# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np

# %%
def get_attention(inputs, mask, n_heads, causal) :
    if n_heads == 1 :
        attention = keras.layers.Attention(causal=causal)(
            [
            inputs, 
            inputs
            ],
            mask=[ 
            mask, 
            mask
            ]
        )
    elif n_heads > 1 :
        attentions = []
        for _ in range(n_heads) :
            attentions.append(
                keras.layers.Attention(causal=causal)(
                    [
                        inputs, 
                        inputs
                    ],
                    mask=[ 
                        mask, 
                        mask
                    ]
                )
            )
        attention = keras.layers.Add()(attentions)
        attention = keras.layers.BatchNormalization()(attention)
    else :
        return inputs
    return attention

def pooling_on_mask(inputs_mask:tf.Tensor) :
    inputs_mask = tf.cast(inputs_mask, tf.int8)
    shape = inputs_mask.get_shape().as_list()
    inputs_mask = keras.layers.Reshape((shape[1], 1))(inputs_mask)
    inputs_mask = keras.layers.MaxPooling1D(pool_size=2, padding='same')(inputs_mask)
    shape = inputs_mask.get_shape().as_list()
    inputs_mask = keras.layers.Reshape((shape[1],))(inputs_mask)
    inputs_mask = tf.cast(inputs_mask, tf.bool)
    return inputs_mask

def get_model(vocab_size, 
              embed_dim, 
              max_len=256, 
              n_attention_heads=6, 
              n_end_attention_heads=0, 
              n_classes=1,
              emb_trainable=True, 
              causal=False, 
              with_pooling=False,
              residual_connections=False,
              global_avg_pool=True,
              decoding_2d=False,
              encoding_2d=False,
              lstm_in_middle=False,
              lstm_on_end=False,
              return_sequences_end=True) :
    inputs      = tf.keras.Input(shape=(max_len,), dtype='int32')
    inputs_mask = tf.keras.Input(shape=(max_len,), dtype='bool')
    mask = inputs_mask

    embedding_layer = keras.layers.Embedding(vocab_size, embed_dim, input_length=max_len, mask_zero=True, trainable=emb_trainable)
    
    embedding  = embedding_layer(inputs)
    last       = embedding
    
    enc_units  = 128
    enc_conv1  = keras.layers.Conv1D(filters=enc_units, kernel_size=3, activation='relu', padding='same')(last)
    last       = enc_conv1
    
    if encoding_2d :
        reshape    = keras.layers.Reshape((max_len, enc_units, 1))(last)
        last       = reshape

        enc_filters = 32
        enc_conv2  = keras.layers.Conv2D(filters=enc_filters, kernel_size=3, strides=(1, 1), activation='relu', padding='same')(last)
        last       = enc_conv2
        
        unshape    = keras.layers.Reshape((max_len, enc_filters * enc_units))(last)
        last       = unshape
        
        drop = keras.layers.Dropout(0.05)(last)
        last  = drop

    last = get_attention(last, mask, n_attention_heads, causal)
    
    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(last)
    last  = conv1
    
    conv2 = keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu', padding='same')(last)
    last  = conv2
    
    if n_end_attention_heads <= 0 or with_pooling:
        pool1 = keras.layers.MaxPooling1D(pool_size=2, padding='same')(last)
        last  = pool1
        if n_end_attention_heads >= 1 :
            mask = pooling_on_mask(mask)
    
    drop = keras.layers.Dropout(0.05)(last)
    last  = drop
    
    conv3 = keras.layers.Conv1D(filters=16, kernel_size=3, activation='relu', padding='same')(last)
    last  = conv3
    
    conv4 = keras.layers.Conv1D(filters=8,  kernel_size=3, activation='relu', padding='same')(last)
    last  = conv4

    if lstm_in_middle :
        lstm = keras.layers.LSTM(units=128, return_sequences=True)(last, mask=mask)
        last = lstm

    pre_attention = last
    last = get_attention(last, mask, n_end_attention_heads, causal)
    
    if lstm_on_end :
        lstm = keras.layers.LSTM(units=128, return_sequences=return_sequences_end)(last, mask=mask)
        last = lstm
    
        if return_sequences_end :
            if decoding_2d :
                features = last.get_shape().as_list()[2]
                reshape    = keras.layers.Reshape((max_len, features, 1))(last)
                last       = reshape

                dec_filters = 32
                enc_conv2  = keras.layers.Conv2D(filters=dec_filters, kernel_size=3, strides=(1, 1), activation='relu', padding='same')(last)
                last       = enc_conv2
                
                unshape    = keras.layers.Reshape((max_len, dec_filters * features))(last)
                last       = unshape
                
                drop = keras.layers.Dropout(0.05)(last)
                last  = drop
    
    if not lstm_on_end or return_sequences_end :
        if global_avg_pool :
            ga_pool = keras.layers.GlobalAveragePooling1D()(last)
            last  = ga_pool
            if residual_connections :
                pre_attention = keras.layers.GlobalAveragePooling1D()(pre_attention)
                last = keras.layers.Concatenate()([last, pre_attention])
        else :
            last = keras.layers.Flatten()(last)
            if residual_connections :
                pre_attention = keras.layers.Flatten()(pre_attention)
                last = keras.layers.Concatenate()([last, pre_attention])
            last = keras.layers.Dense(units=1024, activation='relu')(last)
            last = keras.layers.Dense(units=128, activation='relu')(last)
            last = keras.layers.Dense(units=16, activation='relu')(last)
    
    drop = keras.layers.Dropout(0.05)(last)
    last  = drop

    outputs = keras.layers.Dense(n_classes, activation='sigmoid' if n_classes == 1 else 'softmax')(last)

    model = keras.models.Model(inputs=[inputs, inputs_mask], outputs=outputs)

    model.summary()

    return model, embedding_layer

# %%
model = keras.models.load_model("../resources/output/SST2Processed2/cnn1d_retest/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768.hdf5")

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256)]        0           []
#
#  embedding_2 (Embedding)        (None, 256, 768)     12423936    ['input_5[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 256, 128)     295040      ['embedding_2[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 256, 64)      24640       ['conv1d_10[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 256, 32)      6176        ['conv1d_11[0][0]']
#
#  dropout_4 (Dropout)            (None, 256, 32)      0           ['conv1d_12[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 256, 16)      1552        ['dropout_4[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 256, 8)       392         ['conv1d_13[0][0]']
#
#  input_6 (InputLayer)           [(None, 256)]        0           []
#
#  attention_2 (Attention)        (None, 256, 8)       0           ['conv1d_14[0][0]',
#                                                                   'conv1d_14[0][0]',
#                                                                   'input_6[0][0]',
#                                                                   'input_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 8)           0           ['attention_2[0][0]']
#  alAveragePooling1D)
#
#  dropout_5 (Dropout)            (None, 8)            0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 1)            9           ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 12,751,745
# Trainable params: 12,751,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import pandas as pd
import json

def get_word_index(sentences) :
    all_tokens = []
    for txt in sentences :
        all_tokens += txt.split()

    tokens = pd.Series(all_tokens, range(len(all_tokens)), name="tokens")
    types = tokens.unique()
    word_index = {word : i for i, word in enumerate(["<pad>", "<unk>"] + list(types))}
    
    def decode_review(text):
        reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
        return ' '.join([reverse_word_index.get(i, '?') for i in text])
    
    return word_index, decode_review

def get_dataset(dataframe, word_index, n_classes, max_len=256) :
    index_series, x_series, y_series = dataframe.index, dataframe["text"], dataframe["class"]

    index = list(index_series)

    x_list = [txt.split() for txt in list(x_series)]
    
    x_seq = []
    for tknlst in x_list :
        seq = []
        for tkn in tknlst :
            try :
                seq.append(word_index[tkn])
            except KeyError :
                seq.append(word_index["<unk>"])
        seq = (seq + [0] * (max_len - len(seq))) if (len(seq) < max_len) else (seq[ : max_len])
        x_seq.append(seq)

    x = np.array(x_seq, dtype=int) 
    mask = x != 0
    
    if n_classes == 1 :
        y_int = [1 if lb >= .5 else 0 for lb in list(y_series)]

        y = np.array(y_int, dtype=int) 
    elif n_classes > 1 :
        y = np.zeros((y_series.shape[0], n_classes), dtype=int)
        for i, label in enumerate(list(y_series)) :
            y[i][label] = 1
    else :
        raise Exception()

    return index, x, mask, y

# %%
experiments = [
    # {
    #     "experiment_name" : f"cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_MIDDLE_AND_END_NOTRETSEQ_embed768",
    #     "load_weights_from" : None,
    #     "args" : {
    #         "vocab_size" : None,
    #         "embed_dim" : 768,
    #         "n_classes" : 3,
    #         "n_attention_heads" : 0,
    #         "n_end_attention_heads" : 1,
    #         "emb_trainable" : True,
    #         "lstm_in_middle" : True,
    #         "lstm_on_end" : True,
    #         "return_sequences_end" : False
    #     }
    # },
    # {
    #     "experiment_name" : f"cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_NOTRETSEQ_embed768",
    #     "load_weights_from" : None,
    #     "args" : {
    #         "vocab_size" : None,
    #         "embed_dim" : 768,
    #         "n_classes" : 3,
    #         "n_attention_heads" : 0,
    #         "n_end_attention_heads" : 1,
    #         "emb_trainable" : True,
    #         "lstm_on_end" : True,
    #         "return_sequences_end" : False
    #     }
    # },
    {
        "experiment_name" : f"cnn1d_STARTATTENTION0_ENDATTENTION0_embed768",
        "load_weights_from" : None,
        "args" : {
            "vocab_size" : None,
            "embed_dim" : 768,
            "n_classes" : 3,
            "n_attention_heads" : 0,
            "n_end_attention_heads" : 0,
            "emb_trainable" : True,
        }
    },
    {
        "experiment_name" : f"cnn1d_STARTATTENTION0_ENDATTENTION1_embed768",
        "load_weights_from" : None,
        "args" : {
            "vocab_size" : None,
            "embed_dim" : 768,
            "n_classes" : 3,
            "n_attention_heads" : 0,
            "n_end_attention_heads" : 1,
            "emb_trainable" : True,
        }
    },
    # {
    #     "experiment_name" : f"cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_MIDDLE_embed768",
    #     "load_weights_from" : None,
    #     "args" : {
    #         "vocab_size" : None,
    #         "embed_dim" : 768,
    #         "n_classes" : 3,
    #         "n_attention_heads" : 0,
    #         "n_end_attention_heads" : 1,
    #         "emb_trainable" : True,
    #         "lstm_in_middle" : True 
    #     }
    # },
    {
        "experiment_name" : f"cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768",
        "load_weights_from" : None,
        "args" : {
            "vocab_size" : None,
            "embed_dim" : 768,
            "n_classes" : 3,
            "n_attention_heads" : 0,
            "n_end_attention_heads" : 1,
            "emb_trainable" : True,
            "lstm_on_end" : True 
        }
    }
]

# %%
import os
from statistics import mean

n_folds = 10
dataset_folder = "TwitterAirlines"
dataset_name   = "TweetsProcessed2"
for experiment in experiments :
    checkpoint_dir  = f"../resources/output/{dataset_name}/cnn1d/checkpoint_{experiment['experiment_name']}"
    
    folds_dfs, embeddings_dfs = [], []
    for i_fold in range(n_folds) :
        fold_df       = pd.read_csv(f"../resources/datasets/{dataset_folder}/folds/{dataset_name}_Fold{i_fold + 1}.csv", index_col=0)
        embedding_df = pd.read_csv(f"../resources/embeddings/{dataset_folder}/{dataset_name}_Fold{i_fold + 1}_dim{experiment['args']['embed_dim']}.csv", index_col=0)
        
        folds_dfs.append(fold_df)
        embeddings_dfs.append(embedding_df)
    
    evals = []
    for i_fold in range(n_folds) :
        print("=" * 50)
        checkpoint_path = f"{checkpoint_dir}/fold{i_fold + 1}.hdf5"
        print(checkpoint_path)
        if os.path.exists(checkpoint_path) : continue

        embeddings_df = embeddings_dfs[i_fold]

        train_dataframe = pd.concat(folds_dfs[ : i_fold] + folds_dfs[i_fold + 1 : ])
        valid_dataframe = folds_dfs[i_fold]
        
        word_index, decode_review = get_word_index(train_dataframe["text"])
        if experiment["args"]["vocab_size"] is None :
            experiment["args"]["vocab_size"] = len(word_index)

        ids_train, x_train, mask_train, y_train = get_dataset(train_dataframe, word_index, n_classes=experiment["args"]["n_classes"])
        print(len(ids_train), x_train.shape, mask_train.shape, y_train.shape)
        print(decode_review(x_train[1]), y_train[1])
        
        ids_valid, x_valid, mask_valid, y_valid = get_dataset(valid_dataframe, word_index, n_classes=experiment["args"]["n_classes"])
        print(len(ids_valid), x_valid.shape, mask_valid.shape, y_valid.shape)
        print(decode_review(x_valid[1]), y_valid[1])

        model, emb_layer = get_model(**experiment['args'])

        emb_wgts = emb_layer.get_weights()
        emb_wgts[0][0] = embeddings_df.iloc[0].values
        emb_wgts[0][1 - embeddings_df.shape[0] : ] = embeddings_df.values[1:]
        emb_layer.set_weights(emb_wgts)

        if not experiment['load_weights_from'] is None :
            model.load_weights(experiment['load_weights_from'])
        emb_layer.trainable = experiment['args']['emb_trainable']

        model.compile(optimizer='adam',
                    loss='binary_crossentropy' if experiment["args"]["n_classes"] == 1 else 'categorical_crossentropy',
                    metrics=['accuracy'])
        history = model.fit([x_train, mask_train],
                            y_train,
                            epochs=50,
                            batch_size=64,
                            validation_data=([x_valid, mask_valid], y_valid),
                            callbacks=[
                                keras.callbacks.ModelCheckpoint(
                                    checkpoint_path,
                                    save_best_only=True,
                                    save_weights_only=False,
                                    verbose=1
                                ),
                                keras.callbacks.EarlyStopping(
                                    monitor='accuracy',
                                    min_delta=.0075,
                                    patience=5
                                )
                            ],
                            verbose=1)

        model.load_weights(checkpoint_path)

        preds = model.predict([x_valid, mask_valid])

        if experiment["args"]["n_classes"] == 1 :
            preds_df = pd.DataFrame(preds, index=ids_valid, columns=["predictions"])
            dataset_with_preds_df = pd.concat([valid_dataframe, preds_df], axis=1)
            
            hits, total = 0, 0
            for _, row in dataset_with_preds_df.iterrows() :
                total += 1
                pred  = row["predictions"] >= .5
                label = row["class"]       >= .5
                if pred == label : 
                    hits += 1
            accuracy = hits / total

            hits, total = 0, 0
            for _, row in dataset_with_preds_df.iterrows() :
                total += 1
                pred  = row["predictions"]
                label = row["class"]
                diff = label - pred
                hits += abs(diff)
            avg_dev = hits / total

            true_positives, true_negatives, false_positives, false_negatives = 0, 0, 0, 0
            for _, row in dataset_with_preds_df.iterrows() :
                pred  = row["predictions"] >= .5
                label = row["class"]       >= .5
                if pred == label :
                    if pred :
                        true_positives  += 1
                    else :
                        true_negatives  += 1
                else :
                    if pred :
                        false_positives += 1
                    else :
                        false_negatives += 1
            print(true_positives, true_negatives, false_positives, false_negatives)

            precision = true_positives / (true_positives + false_positives)
            recall = true_positives / (true_positives + false_negatives)
            f1 = (2 * precision * recall) / (precision + recall)

            eval_dict = {
                'model'     : checkpoint_path,
                'accuracy'  : accuracy,
                'precision' : precision,
                'recall'    : recall,
                'f1-score'  : f1,
                'detail'    : {
                    "true_positives"  : true_positives,
                    "true_negatives"  : true_negatives,
                    "false_positives" : false_positives,
                    "false_negatives" : false_negatives
                }
            }
        else :
            preds_df = pd.DataFrame(preds, index=ids_valid, columns=["preds_0", "preds_1", "preds_2"])
            dataset_with_preds_df = pd.concat([valid_dataframe, preds_df], axis=1)
            dataset_with_preds_df.to_csv(f"{checkpoint_dir}/fold{i_fold}-predictions.csv")
            
            hits, total = 0, 0
            for _, row in dataset_with_preds_df.iterrows() :
                total += 1
                pred  = np.argmax([row[col] for col in ["preds_0", "preds_1", "preds_2"]])
                label = row["class"]
                if pred == label : 
                    hits += 1
            accuracy = hits / total
            eval_dict = {
                'model'     : checkpoint_path,
                'accuracy'  : accuracy
            }

        print(eval_dict)

        with open(f"{eval_dict['model']}-eval-dict.json", "w") as f :
            f.write(json.dumps(eval_dict, indent=4))

        evals.append(eval_dict)

        del model 
    if len(evals) == 0 : continue
    final_metrics = {
        "experiment" : experiment["experiment_name"],
        'accuracy'  : mean([fold_metrics["accuracy"] for fold_metrics in evals])
    }
    if 'precision' in evals[0].keys() :
        final_metrics['precision'] = mean([fold_metrics["precision"] for fold_metrics in evals]),
    if 'recall' in evals[0].keys() :
        final_metrics['recall']    = mean([fold_metrics["recall"] for fold_metrics in evals]),
    if 'f1-score' in evals[0].keys() :
        final_metrics['f1-score']  = mean([fold_metrics["f1"] for fold_metrics in evals]),
    if 'detail' in evals[0].keys() :
        final_metrics['detail'] = {
            "true_positives"  : sum([fold_metrics["detail"]["true_positives"]  for fold_metrics in evals]),
            "true_negatives"  : sum([fold_metrics["detail"]["true_negatives"]  for fold_metrics in evals]),
            "false_positives" : sum([fold_metrics["detail"]["false_positives"] for fold_metrics in evals]),
            "false_negatives" : sum([fold_metrics["detail"]["false_negatives"] for fold_metrics in evals])
        }
    with open(f"{checkpoint_dir}/final-eval-dict.json", "w") as f :
        f.write(json.dumps(eval_dict, indent=4))
# Out:
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold1.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold2.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold3.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold4.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold5.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold6.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold7.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold8.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold9.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION0_embed768/fold10.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold1.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold2.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold3.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold4.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold5.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold6.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold7.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold8.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold9.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_embed768/fold10.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold1.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold2.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold3.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold4.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold5.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold6.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold7.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold8.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold9.hdf5
# ==================================================
# ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold10.hdf5
# 13176 (13176, 256) (13176, 256) (13176, 3)
# <start> iad to jfk still has n't boarded what's today's excuse and how am i gon na get to work <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> [1 0 0]
# 1464 (1464, 256) (1464, 256) (1464, 3)
# <start> this is got to be the worst service i've ever seen with an airline 3 cancelled flightled flights rude employees currently flight delayed <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> [1 0 0]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256)]        0           []
#
#  embedding (Embedding)          (None, 256, 768)     9320448     ['input_1[0][0]']
#
#  conv1d (Conv1D)                (None, 256, 128)     295040      ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 256, 64)      24640       ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 256, 32)      6176        ['conv1d_1[0][0]']
#
#  dropout (Dropout)              (None, 256, 32)      0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 256, 16)      1552        ['dropout[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 256, 8)       392         ['conv1d_3[0][0]']
#
#  input_2 (InputLayer)           [(None, 256)]        0           []
#
#  attention (Attention)          (None, 256, 8)       0           ['conv1d_4[0][0]',
#                                                                   'conv1d_4[0][0]',
#                                                                   'input_2[0][0]',
#                                                                   'input_2[0][0]']
#
#  lstm (LSTM)                    (None, 256, 128)     70144       ['attention[0][0]',
#                                                                   'input_2[0][0]']
#
#  global_average_pooling1d (Glob  (None, 128)         0           ['lstm[0][0]']
#  alAveragePooling1D)
#
#  dropout_1 (Dropout)            (None, 128)          0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 3)            387         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 9,718,779
# Trainable params: 9,718,779
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 206/206 [==============================] - ETA: 0s - loss: 0.7422 - accuracy: 0.6881
# Epoch 1: val_loss improved from inf to 0.64629, saving model to ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768\fold10.hdf5
# 206/206 [==============================] - 150s 711ms/step - loss: 0.7422 - accuracy: 0.6881 - val_loss: 0.6463 - val_accuracy: 0.7439
# Epoch 2/50
# 206/206 [==============================] - ETA: 0s - loss: 0.5503 - accuracy: 0.7859
# Epoch 2: val_loss improved from 0.64629 to 0.58855, saving model to ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768\fold10.hdf5
# 206/206 [==============================] - 152s 737ms/step - loss: 0.5503 - accuracy: 0.7859 - val_loss: 0.5886 - val_accuracy: 0.7684
# Epoch 3/50
# 206/206 [==============================] - ETA: 0s - loss: 0.4349 - accuracy: 0.8404
# Epoch 3: val_loss improved from 0.58855 to 0.56693, saving model to ../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768\fold10.hdf5
# 206/206 [==============================] - 152s 737ms/step - loss: 0.4349 - accuracy: 0.8404 - val_loss: 0.5669 - val_accuracy: 0.7787
# Epoch 4/50
# 206/206 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8780
# Epoch 4: val_loss did not improve from 0.56693
# 206/206 [==============================] - 151s 734ms/step - loss: 0.3368 - accuracy: 0.8780 - val_loss: 0.6043 - val_accuracy: 0.7698
# Epoch 5/50
# 206/206 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.9124
# Epoch 5: val_loss did not improve from 0.56693
# 206/206 [==============================] - 151s 731ms/step - loss: 0.2562 - accuracy: 0.9124 - val_loss: 0.6238 - val_accuracy: 0.7883
# Epoch 6/50
# 206/206 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9378
# Epoch 6: val_loss did not improve from 0.56693
# 206/206 [==============================] - 151s 734ms/step - loss: 0.1867 - accuracy: 0.9378 - val_loss: 0.6580 - val_accuracy: 0.7862
# Epoch 7/50
# 206/206 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9492
# Epoch 7: val_loss did not improve from 0.56693
# 206/206 [==============================] - 151s 735ms/step - loss: 0.1517 - accuracy: 0.9492 - val_loss: 0.7928 - val_accuracy: 0.7869
# Epoch 8/50
# 206/206 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9608
# Epoch 8: val_loss did not improve from 0.56693
# 206/206 [==============================] - 150s 727ms/step - loss: 0.1233 - accuracy: 0.9608 - val_loss: 0.7491 - val_accuracy: 0.7678
# Epoch 9/50
# 206/206 [==============================] - ETA: 0s - loss: 0.1038 - accuracy: 0.9668
# Epoch 9: val_loss did not improve from 0.56693
# 206/206 [==============================] - 150s 726ms/step - loss: 0.1038 - accuracy: 0.9668 - val_loss: 0.9402 - val_accuracy: 0.7780
# Epoch 10/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0833 - accuracy: 0.9739
# Epoch 10: val_loss did not improve from 0.56693
# 206/206 [==============================] - 149s 725ms/step - loss: 0.0833 - accuracy: 0.9739 - val_loss: 0.8520 - val_accuracy: 0.7848
# Epoch 11/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9746
# Epoch 11: val_loss did not improve from 0.56693
# 206/206 [==============================] - 149s 722ms/step - loss: 0.0752 - accuracy: 0.9746 - val_loss: 0.9490 - val_accuracy: 0.7575
# Epoch 12/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9772
# Epoch 12: val_loss did not improve from 0.56693
# 206/206 [==============================] - 149s 724ms/step - loss: 0.0703 - accuracy: 0.9772 - val_loss: 0.9824 - val_accuracy: 0.7684
# Epoch 13/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 0.9811
# Epoch 13: val_loss did not improve from 0.56693
# 206/206 [==============================] - 150s 728ms/step - loss: 0.0608 - accuracy: 0.9811 - val_loss: 1.0522 - val_accuracy: 0.7753
# Epoch 14/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9857
# Epoch 14: val_loss did not improve from 0.56693
# 206/206 [==============================] - 149s 723ms/step - loss: 0.0479 - accuracy: 0.9857 - val_loss: 1.0591 - val_accuracy: 0.7766
# Epoch 15/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9836
# Epoch 15: val_loss did not improve from 0.56693
# 206/206 [==============================] - 149s 725ms/step - loss: 0.0543 - accuracy: 0.9836 - val_loss: 1.1390 - val_accuracy: 0.7732
# Epoch 16/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9829
# Epoch 16: val_loss did not improve from 0.56693
# 206/206 [==============================] - 149s 725ms/step - loss: 0.0545 - accuracy: 0.9829 - val_loss: 1.1974 - val_accuracy: 0.7561
# Epoch 17/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9837
# Epoch 17: val_loss did not improve from 0.56693
# 206/206 [==============================] - 149s 722ms/step - loss: 0.0518 - accuracy: 0.9837 - val_loss: 1.1291 - val_accuracy: 0.7589
# Epoch 18/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9872
# Epoch 18: val_loss did not improve from 0.56693
# 206/206 [==============================] - 148s 718ms/step - loss: 0.0432 - accuracy: 0.9872 - val_loss: 1.2230 - val_accuracy: 0.7596
# Epoch 19/50
# 206/206 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9873
# Epoch 19: val_loss did not improve from 0.56693
# 206/206 [==============================] - 148s 719ms/step - loss: 0.0401 - accuracy: 0.9873 - val_loss: 1.2005 - val_accuracy: 0.7602
# 46/46 [==============================] - 5s 88ms/step
# {'model': '../resources/output/TweetsProcessed2/cnn1d/checkpoint_cnn1d_STARTATTENTION0_ENDATTENTION1_LSTM_END_RETSEQ_embed768/fold10.hdf5', 'accuracy': 0.7786885245901639}

# %%
embedding_df
# Out:
#                     1         2         3         4         5         6  \
# <start>     -0.251972 -0.335857  0.743956  0.287609 -0.320067 -0.336197
# to          -0.095761 -0.244435  0.169767 -0.254720  0.520574  0.380848
# the         -0.040541 -1.178647  0.772364  0.711954  0.177214 -0.639962
# i           -0.406263  0.581536  0.150963  0.089914 -0.085831 -0.187691
# a           -0.284253 -0.756383  0.784185  0.245781 -0.217883 -0.411314
# ...               ...       ...       ...       ...       ...       ...
# 1147         0.066911  0.108697  0.117314 -0.026495  0.015199  0.079509
# automated''  0.034742  0.024435 -0.035676 -0.049706  0.029638  0.022952
# 930          0.033926  0.170894  0.087645 -0.031428 -0.038994  0.038913
# screenings   0.195423  0.028148  0.039086 -0.015086 -0.050388  0.027777
# 2464        -0.007101 -0.059626  0.101549 -0.059232  0.012252 -0.152667
#
#                     7         8         9        10  ...       759       760  \
# <start>      0.651577 -0.417630  0.072657  0.669512  ...  0.118542  0.013129
# to          -0.152164  0.410601  0.975136  0.334161  ... -0.455171 -0.563830
# the         -0.159563  0.261875  0.473067 -0.223687  ... -0.444203 -0.343703
# i           -0.108174  0.237551  0.576532  0.273172  ... -0.107218 -0.156319
# a            0.006313 -0.081967 -0.082813 -1.140420  ... -0.822037  0.241155
# ...               ...       ...       ...       ...  ...       ...       ...
# 1147        -0.211216  0.084738 -0.009791  0.068621  ...  0.129855 -0.015207
# automated''  0.011129 -0.154946 -0.134221  0.064848  ... -0.025236 -0.079394
# 930         -0.184922  0.008812 -0.069440  0.067128  ...  0.128920 -0.038195
# screenings  -0.067449  0.064195 -0.061795 -0.068845  ... -0.050059  0.038295
# 2464        -0.161547  0.052095  0.069299 -0.159803  ... -0.024469  0.238262
#
#                   761       762       763       764       765       766  \
# <start>     -0.103702  0.214072  0.223253  0.165746 -0.625366 -0.433057
# to           0.425149 -0.744738  0.315320 -1.070223 -0.815350  0.106142
# the         -0.317150 -0.642309  1.033737  0.581608  0.067017 -0.575224
# i           -0.019238 -0.439631 -0.072913  0.322750 -0.363102  0.098256
# a           -0.176131 -0.117470  0.494665  0.277910 -0.839016 -0.212997
# ...               ...       ...       ...       ...       ...       ...
# 1147        -0.077254 -0.055104 -0.080412  0.157144  0.227705 -0.226615
# automated''  0.159307  0.042786 -0.130191  0.089049 -0.016407 -0.054820
# 930         -0.017345 -0.083919 -0.037820  0.150396  0.248054 -0.204338
# screenings   0.016049  0.132378  0.034546  0.030001  0.030840 -0.048373
# 2464        -0.022484 -0.059594  0.120288  0.039246  0.071109  0.152648
#
#                   767       768
# <start>     -0.647071 -0.493110
# to           0.148487 -0.391389
# the          0.700265 -0.863741
# i           -0.759535 -0.244696
# a           -0.053063 -1.011198
# ...               ...       ...
# 1147        -0.020310  0.101783
# automated''  0.087518  0.114606
# 930         -0.037215  0.093046
# screenings   0.060404  0.080170
# 2464         0.071906 -0.163807
#
# [12134 rows x 768 columns]

# %%
len(word_index)
# Out:
# 12136

# %%
word_index.keys()
# Out:
# dict_keys(['<pad>', '<unk>', '<start>', 'want', 'to', 'book', 'a', 'multi', 'city', 'fare', 'have', 'miles', 'for', '1of', '2', 'flights', 'an', 'option', 'pay', '1st', 'flight', 'with', '2nd', 'ump', 'visa', 'thanks', 'iad', 'jfk', 'still', 'has', "n't", 'boarded', "what's", "today's", 'excuse', 'and', 'how', 'am', 'i', 'gon', 'na', 'get', 'work', '24', 'hrs', 'amp', 'cncld', 'late', 'flightr', "i've", 'landed', 'in', 'phl', 'now', '30', 'mins', 'counting', 'on', 'tarmac', 'waiting', 'gate', 'pls', 'do', 'better', 'than', 'this', 'member', 'of', 'your', 'staff', 'at', 'just', 'gave', 'us', 'excellent', 'customer', 'care', 'shame', 'the', 'same', 'could', 'be', 'said', 'past', 'hours', 'there', 'was', 'closure', 'people', 'here', 'need', 'inform', 'passengers', 'not', 'send', 'them', 'w', 'no', 'info', 'boards', 're', 'updated', 'departures', '14', 'sorry', 'it', 'oh', 'well', 'screw', 'weekend', 'az', 'right', 'eat', 'hotel', 'problem', 'been', 'france', 'two', 'days', 'without', 'changing', 'clothes', 'nothing', 'keep', 'me', 'warm', 'so', 'please', 'locate', 'my', 'bag', '4', 'if', 'united', 'loses', 'baggage', 'they', 'will', 'airport', 'country', 'then', 'disappears', "it's", 'time', 'our', 'go', 'explain', 'why', 'every', 'other', 'dallas', 'is', 'going', 'out', 'today', 'except', '635', 'pm', 'direct', 'number', 'call', 'request', 'refund', 'its', 'telling', 'valid', 'as', 'changed', 'ticket', 'site', 'too', 'impressed', 'airlines', 'but', 'would', 'feel', 'lot', 'flying', 'you', 'upgraded', 'up', 'first', 'class', 'tomorrow', 'doing', 'musicians', 'real', 'dirty', 'lax', 'never', 'blocked', 'from', 'getting', 'bass', '8', 'hotels', '32', 'like', 'we', 'are', 'being', 'held', 'hostage', 'because', 'someone', 'boarding', 'passes', 'ca', 'leave', 'heard', 'u', 'might', 'imagine', 'former', 'pilot', 'particularly', 'touched', 'by', 'gesture', 'let', 'fo', 'know', '20', 'minutes', 'hold', 'ridiculous', 'much', 'lesson', 'plans', 'music', 'classes', 'very', 'long', 'day', 'philly', '1213pm', 'flt', 'ord', 'cancelled', 'flighted', 'notice', 'message', 'email', 'nice', 'platinums', 'wjere', 'luggage', 'slow', 'one', 'traveling', 'asking', 'sister', 'who', 'nephew', 'midland', 'eventually', '85681', 'cost', 'round', 'trip', 'tickets', 'yes', 'says', 'delivered', 'local', 'open', 'asked', 'main', 'cust', 'service', 'got', 'hung', 'assistance', 'due', 'incompetence', 'reschedule', 'connection', 'fly', 'again', 'about', 'when', 'can', 'see', 'new', 'american', 'credit', 'card', 'replace', 'usairways', 'dividend', 'mastercard', 'apologies', 'required', 'made', 'home', 'safe', 'kudos', 'aa', 'speak', '2hours', 'guys', 'nogood', 'team', 'offer', 'access', 'journal', 'digital', 'lovely', 'inflight', 'makes', 'experience', 'booked', 'sept', 'best', 'price', 'april', 'usa', 'checked', '67', 'cheaper', 'what', 'con', 'unhappy', 'ua1159', 'denver', 'cheduled', '5', 'times', 'show', "you'll", 'trying', 'make', 'online', 'booking', 'problems', 'way', 'barbados', 'nyc', 'wont', 'cc', 'e', '0162389030167', '16866853', 'case', 'id', '8465981', 'handler', 'dtw', '21', '710', 'ran', 'bags', 'hitting', 'ground', '9', 'degree', 'temp', 'empathizes', 'disappointment', 'that', '1stclass', 'wnonworking', 'entertainmnt', 'worth', '50', 'checking', 'plane', 'before', 'having', 'everyone', 'board', 'definitely', 'done', 'hell', 'put', "you've", 'stranded', 'mechanical', 'issues', 'weather', 'worst', '180', 'fee', '200', "it''", 'accommodate', 'given', 'circumstances', 'bos', 'really', "lost''", 'another', 'knowledge', 'were', 'sure', 'ty', 'ever', 'all', 'busy', 'storm', 'should', 'always', 'point', 'more', 'disappointed', 'back', 'boston', 'pr', 'flightled', 'rebooked', 'next', 'delayed', 'compensation', 'glad', 'fix', 'dm', 'confirmation', 'check', 'sign', 'he', 'status', 'exp', 'membership', 'physical', 'some', 'international', 'lounges', 'soon', 'phone', 'supervisor', 'regarding', 'travels', 'flightst', 'ad', 'happy', 'few', 'worked', 'had', 'postpo ...

# %%
i_fold = 3

embeddings_df = embeddings_dfs[i_fold]

train_dataframe = pd.concat(folds_dfs[ : i_fold] + folds_dfs[i_fold + 1 : ])
valid_dataframe = folds_dfs[i_fold]

word_index, decode_review = get_word_index(train_dataframe["text"])
if experiment["args"]["vocab_size"] is None :
    experiment["args"]["vocab_size"] = len(word_index)

ids_train, x_train, mask_train, y_train = get_dataset(train_dataframe, word_index, n_classes=experiment["args"]["n_classes"])
print(len(ids_train), x_train.shape, mask_train.shape, y_train.shape)
print(decode_review(x_train[1]), y_train[1])

ids_valid, x_valid, mask_valid, y_valid = get_dataset(valid_dataframe, word_index, n_classes=experiment["args"]["n_classes"])
print(len(ids_valid), x_valid.shape, mask_valid.shape, y_valid.shape)
print(decode_review(x_valid[1]), y_valid[1])
# Out:
# 13176 (13176, 256) (13176, 256) (13176, 3)
# <start> iad to jfk still has n't boarded what's today's excuse and how am i gon na get to work <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> [1 0 0]
# 1464 (1464, 256) (1464, 256) (1464, 3)
# <start> was in a line a mile long at sky harbor this morning your staff was courteous and <unk> thank you <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> [0 0 1]

# %%
embeddings_df
# Out:
#                   1         2         3         4         5         6  \
# <start>   -0.282846 -0.485796 -0.038414  0.352181 -0.564837  0.169060
# to        -0.415130 -1.033926  0.068353  0.440023 -0.405840  0.913767
# the        0.642369 -0.869593  0.740655  0.698861 -0.100020 -0.076253
# i          0.158433 -0.469385 -0.073635 -0.132904 -0.902013  0.510985
# a         -0.111537 -0.689202  0.877903 -0.269690  0.183240  0.115914
# ...             ...       ...       ...       ...       ...       ...
# renewed    0.074851 -0.038765 -0.051553  0.026132  0.056374 -0.123528
# ua761      0.030084 -0.010749 -0.053900 -0.006302  0.080238  0.077685
# moves      0.022142 -0.021479  0.128811 -0.018625  0.078715 -0.000661
# clockwork -0.112291 -0.067761 -0.064172  0.096315  0.094721 -0.001640
# ctg        0.032709 -0.091708  0.086493  0.038489 -0.020235 -0.088093
#
#                   7         8         9        10  ...       759       760  \
# <start>    0.218938  0.147674  0.519879  0.071983  ...  0.788335  0.355169
# to        -0.697176 -0.593707  0.068347 -0.544617  ...  0.463278 -0.190466
# the       -0.532491  0.089165  0.047654  0.244985  ...  0.431776 -0.542156
# i         -0.734310  0.219299  0.671551 -0.015053  ...  0.668103  0.064029
# a         -0.101982  0.018584 -0.157449 -0.158345  ...  1.076107 -0.535732
# ...             ...       ...       ...       ...  ...       ...       ...
# renewed   -0.042322  0.163471 -0.216049 -0.074544  ...  0.050555  0.096236
# ua761      0.000377  0.058809  0.109591  0.121032  ... -0.053510 -0.164922
# moves     -0.105004  0.058264 -0.063435 -0.002328  ...  0.061755  0.070977
# clockwork  0.099411 -0.083651  0.160123 -0.050896  ... -0.037912 -0.173050
# ctg       -0.033689 -0.110713 -0.031637  0.000049  ...  0.014714  0.193294
#
#                 761       762       763       764       765       766  \
# <start>   -0.353737 -0.654546 -0.739606  0.774340  0.977387 -0.108453
# to        -0.006372 -1.845080 -1.871068  0.187292  1.300340 -0.927931
# the       -0.986821 -1.289415 -0.163144  1.409486  0.956747 -0.454120
# i         -0.218738 -1.440547 -1.043749  0.685961  1.527858 -0.738634
# a         -0.057149 -1.205376 -1.086794  1.163292  1.485147 -1.402447
# ...             ...       ...       ...       ...       ...       ...
# renewed   -0.121695 -0.147618 -0.042536  0.047722  0.096364  0.018134
# ua761      0.125757  0.041468 -0.036388  0.021465  0.004651 -0.082069
# moves     -0.020302 -0.048003  0.011098  0.005438  0.081405 -0.020868
# clockwork -0.009925 -0.069573 -0.144182  0.300522  0.064133 -0.018481
# ctg       -0.040438 -0.235827 -0.036547  0.088389  0.014299 -0.064934
#
#                 767       768
# <start>   -0.701812  1.476708
# to        -0.190056  1.390106
# the       -0.163223  0.987065
# i         -1.085329  1.415565
# a          0.400378  0.712581
# ...             ...       ...
# renewed    0.059003 -0.029817
# ua761      0.001113  0.006983
# moves     -0.023329  0.039025
# clockwork -0.056886  0.087694
# ctg        0.059912 -0.005553
#
# [12127 rows x 768 columns]

# %%
len(word_index)
# Out:
# 12129
