# %%
import numpy as np
import pandas as pd
import os, json, math

os.getcwd()
# Out:
# 'c:\\Users\\T-Gamer\\Documents\\SideDrive\\UFMA\\2022.1\\Topicos Especiais (NLP)\\Exercicios\\Trabalho Final\\Implementação\\source'

# %%
import torch

# %%
from transformers import AutoModelForSequenceClassification

# %%
def levenshtein(source:str, target:str) -> int :
    n = len(source)
    m = len(target)
    
    D = np.zeros((n + 1, m + 1), dtype=int)
    for i in range(1, n + 1) :
        D[i][0] = D[i - 1][0] + 1
    for j in range(1, m + 1) :
        D[0][j] = D[0][j - 1] + 1

    subst_cost = lambda x, y : 0 if x == y else 4
    for i in range(1, n + 1) :
        for j in range(1, m + 1) :
            D[i][j] = min([D[i - 1][j    ] + 1,
                           D[i - 1][j - 1] + subst_cost(source[i - 1], target[j - 1]),
                           D[i    ][j - 1] + 1])
    return D[n][m]
def distance(source:str, target:str) -> float :
    lev = levenshtein(source, target)
    if source in target or target in source : lev = lev - .5 
    return lev

# %%
class Dataset(torch.utils.data.Dataset) :
    def __init__(self, 
                 dataframe:pd.DataFrame, 
                 vocabulario:list[str],
                 translation_dict:dict[str,str]=None,
                 max_length:int=512,
                 text_column:str='text',
                 label_column:str='class',
                 n_classes:int=1) :
        self.dataframe = dataframe
        self.vocabulario_original = vocabulario
        self.vocabulario_dict = {word : i for i, word in enumerate(self.vocabulario_original)}
        
        vocabulario_real = []
        for txt in list(self.dataframe[text_column]) :
            vocabulario_real += txt.split()
        vocabulario_real = list(pd.Series(vocabulario_real).unique())
        
        if translation_dict is None :
            self.new_words = {}
        else :
            self.new_words = translation_dict
            for new, translation in translation_dict.items() :
                self.vocabulario_dict[new] = self.vocabulario_dict[translation]
        
        for tkn in vocabulario_real :
            if not tkn in self.vocabulario_dict.keys() :
                voc_sort = list(self.vocabulario_dict.keys())
                voc_sort.sort(key=lambda x : distance(tkn, x))
                print(tkn, "to", voc_sort[0])
                self.new_words[tkn] = voc_sort[0]
                self.vocabulario_dict[tkn] = self.vocabulario_dict[voc_sort[0]]
        print("No. new words:", len(self.new_words))
        
        self.max_length = max_length
        self.text_column = text_column
        self.label_column = label_column
        self.n_classes = n_classes
    def __len__(self) :
        return self.dataframe.shape[0]
    def text_processing(self, text:str) :
        tokenlist = text.split()
        
        sequence = []
        for token in tokenlist :
            sequence.append(self.vocabulario_dict[token] + 1)

        mask = [1 for _ in range(len(sequence))]
        if len(sequence) > self.max_length :
            sequence = sequence[ : self.max_length]
            mask = mask[ : self.max_length]
        else :
            padding = [0 for _ in range(self.max_length - len(sequence))]
            sequence = sequence + padding
            mask = mask + padding
        
        return sequence, mask

    def __getitem__(self, index) :
        if type(index) == int :
            sequence, mask = self.text_processing(self.dataframe.iloc[index][self.text_column])
            label = self.dataframe.iloc[index][self.label_column]
            label = [label]
            label = torch.tensor(label)
            return {
                    'sentence_ids'      : self.dataframe.iloc[index].name,
                    'input_ids'      : torch.tensor(sequence),
                    'attention_mask' : torch.tensor(mask),
                    'labels'         : label
                }
        elif type(index) == slice :
            start = index.start
            if start == None : start = 0
            stop = index.stop
            if stop == None or stop > len(self) : stop = len(self)
            
            sentence_ids = []
            input_ids, attention_mask, labels = [], [], []
            for i in range(start, stop) :
                item = self[i]
                sentence_ids.append(item["sentence_ids"])
                input_ids.append(item["input_ids"])
                attention_mask.append(item["attention_mask"])
                labels.append(item["labels"])

            input_ids_tensor = torch.tensor([list(sentence) for sentence in input_ids])
            attention_mask_tensor = torch.tensor([list(sentence) for sentence in attention_mask])
            labels_tensor = torch.tensor([list(sentence) for sentence in labels])
            
            return {'sentence_ids'   : sentence_ids,
                    'input_ids'      : input_ids_tensor,
                    'attention_mask' : attention_mask_tensor,
                    'labels'         : labels_tensor}
        else :
            raise IndexError()

# %%
# Para dataset simples, sem folding
# Args
resource_folder = "../resources"
dataset_folder = "StanfordSentimentTreebank"
dataset_name   = "SST2Processed2"
dataset_split   = "test"
batch_size = 16

# %%
# Exec
embeddings_df = pd.read_csv(f"{resource_folder}/embeddings/{dataset_folder}/{dataset_name}-train_dim768.csv",        index_col=0)
dataset_df    = pd.read_csv(f"{resource_folder}/datasets/{dataset_folder}/split/{dataset_name}-{dataset_split}.csv", index_col=0)

output_dir    = f"../resources/output/{dataset_name}-Eval"

translation_dict_path = f"{resource_folder}/datasets/{dataset_folder}/split/{dataset_name}-test-new-words.json"
if os.path.exists(translation_dict_path) :
    with open(f"{resource_folder}/datasets/{dataset_folder}/split/{dataset_name}-test-new-words.json", "r") as f :
        new_words = json.loads(f.read())
else :
    new_words = None
dataset = Dataset(dataset_df, embeddings_df.index.tolist(), new_words)
# Out:
# wasabi to wasabi's
# showed to show
# curls to curse
# fed to ed
# ponders to ponder
# it' to it
# author to author's
# enrapturing to featuring
# tempt to attempt
# inscrutable to suitable
# bleakly to bleak
# professionalism to professionals
# latent to late
# gangsta to angst
# shook to hook
# rattled to rated
# deceptive to deceptively
# grimness to dimness
# fatalist to fatalism
# worldview to world
# lobbies to lies
# roadside to broadside
# cafes to cares
# permeate to permeates
# outings to outing
# cartoonlike to cartoon
# magnet to magnetic
# fuller to full
# karmen to karen
# chanting to enchanting
# braided to aided
# wipe to swipe
# jeweled to welled
# beads to ads
# lacerating to lactating
# old' to old
# 50's to 50s
# cheesiness to cheesiest
# johnson's to son's
# orchestrates to orchestrated
# siberian to brian
# sheep to she
# hosts to host
# parka to park
# everytime to every
# rips to rip
# 1998's to 1998
# uncontrolled to controlled
# farther to father
# quietness to quiet
# buildup to build
# maverick to eric
# shadings to shaking
# coloring to color
# treebeard to beard
# gollum's to glum
# performance' to performance
# aberration to narration
# originally to original
# isle to is
# misogynistic to misogynist
# tok to to
# orchestrate to orchestrated
# overpraised to praised
# catchy to catch
# spycraft to craft
# damon's to damon
# katz to at
# lynchings to synching
# recordings to recording
# meeropol to metropolis
# anthropologically to anthropology
# suburbia to suburban
# interstitial to initial
# disappear to disappears
# vertiginous to serious
# embers to members
# dormant to dorm
# calcified to life
# chronic to chronicle
# irwin's to irwin
# hemmingway to humming
# accelerated to celebrated
# piesiewicz's to pies
# veronique to everyone
# sl2 to 2
# pabst to past
# ribbon to bon
# du to due
# sarcasm to sara
# andrew to drew
# quizzical to qual
# syncopated to coated
# mimicking to kicking
# puffery to puff
# obviation to obligation
# illusions to illusion
# erasing to raising
# recasts to casts
# gambol to gamble
# fluidly to fluid
# comedians to comedian
# truth' to truth
# deconstructing to deconstruction
# doubtless to doubles
# blessing to bless
# responsive to response
# koreans to korean
# gourmet to gourmet's
# thru to thrust
# strap to trap
# frontier to front
# logistical to logistically
# milestone to milestones
# schweiger to schweig
# steak to streak
# minefield to field
# gorefests to gorefest
# connoisseur to connoisseurs
# coarseness to coarse
# quills to ills
# cent to recent
# stump to sum
# speech to pee
# hogs to hos
# punishing to pushing
# plausibility to implausibility
# partially to partly
# minty to monty
# underwritten to written
# fooled to fool
# prizes to pies
# yvan's to yvan
# rambunctious to ambitious
# jew to jews
# happiest to happens
# premises to premise
# backs to back
# commodity to community
# homespun to homes
# mule to le
# skinner to inner
# posse to pose
# seaworthy to worthy
# fantastical to fantastic
# sock to stock
# makmalbaf to makhmalbaf
# kurdish to kurds
# borderlands to borders
# chunk to hunk
# pinch to inc
# tartness to artless
# tribulations to contributions
# willams' to williams'
# ebb to b
# deposits to posits
# freeway to free
# headache to headaches
# exhilarate to exhilarating
# beanie to bean
# materials to material
# escalating to eating
# admired to admire
# latifah to latin
# flaunting to haunting
# contradictions to contradiction
# diverted to diver
# lightens to lighten
# chimpanzees to chimps
# surgical to serial
# questing to question
# racked to cracked
# loathing to floating
# genet to net
# rechy to preachy
# fassbinder to aside
# nocturnal to natural
# goya to go
# badge to bad
# permutations to equations
# clashes to clash
# headlines to headline
# 1995 to 19
# crystalline to crystallize
# implicit to simplicity
# americana to american
# fictionalize to fictional
# uncommercial to commercial
# visits to visit
# grasped to grasp
# composing to posing
# preteens to preteen
# nonthreatening to threatening
# o's to ho's
# offs to off
# fastidiousness to seriousness
# ellefsen to ellen
# frailties to families
# magnified to magnificent
# vex to ex
# petin's to pete's
# penetrates to generates
# tantalizing to amazing
# provocatuers to provocateur
# aroused to used
# mideast to ideas
# perceptively to perceptive
# barris to barris'
# jirí to jr
# hubac's to has
# silberstein to silbersteins
# additional to addition
# ribald to bald
# shapelessly to shapeless
# gratifying to gratify
# appraisal to april
# torpor to toro
# jie's to jie
# intently to intent
# abuses to abuse
# regimes to regimen
# figurative to figure
# port to sport
# dock to doc
# unloading to leading
# testify to test
# comparative to comparatively
# vardalos' to vardalos
# inhabited to inhabit
# incendiary to diary
# venomous to enormous
# bigotries to tries
# theocracy to theory
# wrench to french
# antithesis to thesis
# dazzlingly to dazzling
# münch's to munch's
# overindulgence to indulgence
# deteriorating to deterioration
# croc to rock
# disrupts to dips
# specialty to special
# endearingly to endearing
# soviet to movie
# russia to russian
# bishop to shop
# standouts to standout
# bastions to basis
# ikea to ke
# blurred to lured
# remembers to remember
# transferral to feral
# sanded to sand
# microcosm to croc
# dabbling to bling
# creamy to cream
# authors to author
# battista to artist
# aspiring to spring
# directress to directors
# breezily to breezy
# apolitical to political
# gawk to gawky
# applaud to applauded
# wallpaper to paper
# hu to hug
# glint to lint
# raja to rama
# enthuse to thus
# andersson's to anderson's
# rigorous to rigors
# distancing to dancing
# movingly to moving
# 179 to 19
# explorations to exploration
# magimel to magi
# dennis to denis
# weakened to weaned
# supportive to support
# ethnicity to ethnic
# valedictory to actory
# shards to hard
# gyro to go
# bartleby' to bartleby
# farrell to farrelly
# foil to fil
# willis's to willis
# colonel to clone
# conditioned to condition
# saucer to sucker
# downy to down
# cheeked to cheek
# moppets to mopes
# empathetic to pathetic
# bennett's to benefits
# descent to decent
# breakup to break
# johnson to johnson's
# sayles' to sayles
# wordplay to worldly
# preference to reference
# indomitable to inimitable
# ostentatious to tenacious
# american's to americans
# randy to and
# figuratively to figurative
# lucía to luc
# arousing to rousing
# renner's to renner
# enthusiast to enthusiasts
# rhythmic to rhythm
# dazzles to dazzle
# adulthood to adult
# fraught to caught
# wannabes to wannabe
# addessi to address
# beatrice to beat
# jones' to jones
# fidelity to infidelity
# melding to mending
# reflecting to reflection
# heartbeat to heartbreak
# heartedly to hearted
# longley to longley's
# horrifically to horrific
# bangs to bang
# pleaser's to pleaser
# spunk to punk
# gruelling to grueling
# wollter's to wollter
# rockwell to stockwell
# vastness to vanessa
# comprehensive to comprehensible
# beaut to beauty
# bundy to und
# reilly to really
# octopus to cops
# deceivingly to receiving
# retrospect to retrospective
# ana to an
# lick to flick
# tep to step
# likability to liability
# increments to clements
# camouflaged to camouflage
# brazil' to brazil
# adoration to duration
# hogwarts to hogwash
# mischief to chief
# redgrave to redgrave's
# aquatic to quick
# baja to ba
# peninsula to insular
# mexico to mexico's
# fizzles to fizzle
# symmetry to summery
# patois to pathos
# tossing to toss
# bellini to elling
# mullinski to mulls
# compact to pact
# breezes to breezy
# wink to win
# sardine to sade
# value' to value
# wimp to wimps
# cried to crime
# relocation to location
# displayed to display
# 33 to 3
# inexperience to inexperienced
# division to divisions
# flotsam to lots
# unearthed to unearth
# takers to takes
# sandwiched to sandwich
# rending to ending
# elliott's to it's
# fashions to fashion
# connects to connect
# ranging to raging
# gathers to fathers
# l'avventura to ventura'
# repulsion to revulsion
# congeals to conceal
# tingle to tinge
# barbershop' to barbershop
# anytime to daytime
# narcotizing to acting
# biennial to genial
# ensnaring to endearing
# indicates to indicate
# oblivion to oblivious
# examined to examine
# villeneuve's to villeneuve
# intuitively to punitively
# squalor to qual
# bared to bare
# confronted to confront
# stealth to steal
# precollegiate to collegiate
# liberated to literate
# hogan's to chan's
# reno's to reno
# trumpets to trumpet
# headlong to along
# delinquent to delinquent'
# timeframe to frame
# peterspider to spider
# cozy to coy
# myths to myth
# spun to pun
# afresh to fresh
# arouse to aroused
# unknowing to knowing
# resolute to resolutely
# nakedness to naked
# preciously to precious
# interwoven to intern
# positions to position
# mull to mulls
# stimulates to stimulate
# unobtrusively to intrusive
# version's to versions
# plentiful to pitiful
# manipulate to manipulative
# saturation to situation
# bombing to bomb
# glass' to glass
# divining to driving
# confirmation to configurations
# unelected to neglected
# incurious to curious
# uncharismatic to charismatic
# overgrown to grown
# whiplash to whip
# glad to lad
# stopping to topping
# unmentioned to mentioned
# yimou to you
# amalgamating to amalgam
# relax to relaxed
# treat' to treat
# undoubted to undoubtedly
# extensions to extension
# charmers to charmer
# miraculously to miraculous
# excessive to excessively
# sparklingly to sparkling
# raiser to raise
# bonehead to head
# deciding to ending
# affirmation to affirmational
# deedbad to dead
# deed to deeds
# reversals to reversal
# sinner to inner
# symmetrical to serial
# unaccustomed to accused
# degrees to degree
# shy to sy
# contests to contest
# griffin's to griffin
# testimonials to testimonial
# artifact to artefact
# arena to area
# barrett to brett
# browning to brown
# hmm to hmmm
# packs to pack
# nurturing to turning
# gauzy to guy
# dithering to adhering
# zigs to zings
# zags to as
# projected to project
# dreyfus to refuse
# patterns to matters
# ideals to ideal
# 1950 to 1950s
# swashbuckling to swashbucklers
# fatality to fatalist
# classism to classics
# ignorance to ignore
# potatoes to potato
# shticks to shtick
# sympathetically to pathetically
# personifying to personified
# purest to rest
# intimidating to imitating
# horrorthriller to thriller
# staging to stagings
# intertwined to intentioned
# moretti's to moretti
# blobby to lobby
# superlarge to large
# changer to change
# evaluation to devaluation
# guidance to dance
# invade to invaders
# abundance to sundance
# mindsets to mindset
# fanatically to fanatical
# fetishized to fetishes
# idiosyncrasy to idiosyncratic
# monastic to most
# majesty to majestic
# slipper to slippery
# holidays to holiday
# incarnates to incarnations
# prophetic to prophet
# exacting to acting
# patronized to parodied
# crafts to craft
# see' to see
# incandescent to indecent
# stupendous to spends
# unquestionably to questionable
# bedouins to begins
# softest to softens
# revolt to revolting
# cuff to puff
# stylishness to stylish
# gunning to running
# bow's to bow
# preschool to school
# humored to humor
# charmingly to charming
# depicting to depiction
# bola to la
# peeved to pee
# nalin to lin
# weigh to weight
# loosey to loose
# goosey to goose
# destinees to destin
# sheen to seen
# bedevils to devils
# soldier to soldiers
# 45 to 5
# teamwork to work
# molony to moon
# simon to simone
# parisian to paris
# rebirth to bit
# ensnared to ensnare
# almodóvar to almodovar
# ferocious to serious
# gosh to go
# quests to quest
# courting to outing
# abbass to abbass's
# actualization to realization
# continental to continent
# divides to divided
# profiles to profile
# owners to ones
# another's to another
# dominatrixes to dominates
# characterizing to characterization
# tailored to tailor
# knots to not
# scuzbag to cuba
# delicacy to delay
# surpassed to passed
# empress to press
# leoni's to leone's
# ellie to elie
# recapturing to capturing
# pauses to pause
# locked to clocked
# mold to old
# herek's to here's
# wine to win
# bottles to battles
# hornby's to horns
# idoosyncratic to idiosyncratic
# terrain to train
# trio's to trio
# niccol's to niccol
# screenplay's to screenplays
# sappier to spider
# hook's to hooks
# assuredness to assured
# pigeonhole to hole
# resisting to resist
# reinforces to forces
# antidotes to antidote
# convert to converts
# elmer to helmer
# bernstein's to einstein's
# melodic to mel
# inch to inc
# shambling to rambling
# custom to tom
# scams to scam
# hornby to hornby's
# belated to bloated
# ride's to bride's
# bumpy to bump
# lap to slap
# ta to a
# carion's to carlito's
# hums to hum
# dyspeptic to septic
# theirs to their
# mirth to smith
# youngster to youngsters
# frisky to risky
# exporing to exploring
# chin to china
# marketplace to replace
# amusingly to amusing
# coincidences to coincidence
# make'em to make
# shading to shadings
# ross's to rose's
# specials to special
# entrancing to enhancing
# darn to dan
# smarty to smart
# aura to laura
# balletic to ballet
# agreeable to agreeably
# pal's to paul's
# epochs to epics
# sampling to smiling
# inequities to inquiries
# immorality to morality
# administration to administration's
# misperception to perception
# appalled to applied
# shinya to shiny
# tsukamoto's to sam's
# iron to irony
# 180 to 80
# fiascoes to fiascos
# benoit to bent
# heaving to having
# puccini's to pacino's
# fandango to danang
# abbas to abbass
# charly' to charly
# divide to divided
# befuddlement to element
# marvellous to marvelous
# earthshaking to shaking
# fluctuating to lactating
# humanitarian to humanity
# stars' to stars
# unlucky to lucky
# cassette to asset
# def to de
# leppard's to lear's
# pyromania to roman
# fandom to random
# combo to com
# closeness to looseness
# unreality to reality
# andersson to anderson
# hoops to oops
# plump to lump
# fulsome to some
# reinforced to enforced
# rookie to cookie
# quantum to quaint
# brilliant' to brilliant
# picking to kicking
# potholes to porthole
# befall to fall
# brethren to breathe
# dives to dive
# turfs to turf
# reviewing to viewing
# obscurities to obscure
# miniscule to mini
# bleep to lee
# oiled to boiled
# upholstered to bolstered
# sickness to slickness
# rara to ararat
# avis to davis
# hawke to hawk
# articulated to articulate
# flights to flight
# burdette's to bette
# utmost to most
# economy to economic
# samantha to santa
# viewfinder to viewer
# master's to master'
# compulsive's to compulsive
# cadness to sadness
# candidly to candid
# westfeldt to west
# juergensen to urges
# territories to territory
# crit to it
# types' to types
# elizabethan to elizabethans
# shagster to shatner
# casey to case
# kasem to as
# furnished to finished
# amongst to among
# representations to representation
# contacts to contact
# hosts' to hosts
# guests' to guest
# tastes to taste
# foreboding to reading
# jazzes to jazz
# adroitly to adroit
# madame to adam
# refer to prefer
# jackie' to jackie
# spates to spat
# translates to translate
# hors to horse
# d'oeuvre to oeuvre
# filmic to film
# sizzling to smiling
# reconsideration to consideration
# francisco's to francisco
# fountainheads to fontaine's
# pawns to pawn
# bishops to bishop
# kings to king
# wagers to agers
# dingy to ing
# backrooms to brooms
# forests to forest
# leisurely to surely
# reject to rejects
# python's to python
# weaver's to weaver
# discontented to discontent
# 1983's to 1998's
# koyaanisqatsi to anti
# 1988's to 1998's
# powaqqatsi to qatsi'
# naqoyqatsi to naqoyqatsi'
# nations to nation
# inventively to inventive
# extols to ethos
# comradeship to comes
# spunky to spunk
# retribution to repetition
# futures to future
# modulated to muted
# kaputschnik to puts
# despondent to dependent
# renown to reno
# dolgin to dog
# eagerly to eager
# infecting to affecting
# pasadena to sade
# elvira's to elvira
# hooters to hookers
# binds to bind
# mistaking to taking
# grass to grasps
# melrose to rose
# erika to era
# mod to mo
# of'60s to of'70s
# kickass to kicks
# beau to beaut
# travil to trail
# nenette to nanette
# boni to bon
# perverted to perverse
# riff to riffs
# creator to creators
# simplest to simple
# australia's to australia
# flaky to fly
# bizarrely to bizarre
# splittingly to spittingly
# piper to pipe
# perabo to era
# magnificence to magnificent
# chorus to chou
# damsels to damsel
# winsome to some
# premier to premise
# sarcastic to arctic
# shield to held
# outta to out
# tierney to tier
# choking to chong
# engulfing to beguiling
# allying to lying
# defeat to defeats
# resonates to resonate
# comparable to parable
# renoir to reno
# subtleties to subtle
# ramsay's to ramsay
# resent to present
# professes to presses
# giddily to giddy
# francophiles to franchise
# snicker to snickers
# knowingly to knowing
# caution to cautions
# hedonist to hedonistic
# aborbing to absorbing
# arguable to arguably
# hallucinations to hallucinatory
# toe to to
# 1955 to 19
# monkeyfun to monkey
# bounties to bones
# artifacts to artifact
# st to t
# petersburg's to pete's
# hawn's to hawn
# bluntly to blunt
# newold to new
# exigencies to experiences
# adorned to adored
# pleasurably to pleasurable
# jacked to jack
# philibert to pile
# observes to observe
# schoolhouse to schools
# truffle to ruffle
# dainty to any
# psychopathy to psychopathic
# ecologically to ecological
# teaches to teachers
# unconventionally to unconventional
# venerable to vulnerable
# reheated to heated
# weeping to sweeping
# more's to moore's
# relaxing to relating
# viewings to viewing
# lauren to laurence
# puzzlement to puzzle
# symbolizes to symbolism
# alzheimer's to dahmer's
# interacting to interaction
# eyeball to eyeballs
# dragon' to dragon
# noses to nose
# endedness to tenderness
# 11th to 11
# barbecue to rescue
# mindedly to minded
# presuppose to suppose
# bigotry to gory
# zealous to zealously
# nuttiness to business
# antagonists to antagonism
# impartiality to martial
# atom to tom
# broached to branched
# nonagenarian to again
# boldness to bones
# pentecostal to pedestal
# dallas to alas
# services to service
# warthog to warmth
# hyperbole to hyperbolic
# bravely to brave
# delve to delves
# fictions to fiction
# peddled to padded
# holocaust' to holocaust
# jakob to job
# allegorical to allegory
# quench to punch
# josef to jose
# bierbichler to richer
# monica to moronic
# bleibtreu to bite
# helene to lee
# weigel to gel
# andy to and
# richest to chest
# ricci's to rice's
# thwart to that
# nathan to than
# crummles to rules
# bustingly to busting
# weakest to weak
# thinnest to thinness
# sleepy to sleep
# declares to declared
# yang to hyang
# expressed to express
# 82 to 2
# bend to end
# architectural to architecture
# glories to goes
# connecting to connection
# historians to historical
# the' to the
# 70's to 70s
# viciously to vicious
# griping to gripping
# buddies to dies
# garry to gary
# shandling to handling
# unsettlingly to unsettling
# deceitful to deceit
# idealistically to realistically
# selfless to useless
# coldly to cold
# unselfconscious to conscious
# munch to much
# invariably to inevitably
# cockamamie to come
# precipitously to preciously
# catastrophe to catastrophic
# wracking to waking
# screamingly to screaming
# sturdy to study
# judges to judge
# overcook to overcooked
# 1982 to 19
# recital to real
# gainsbourg's to gainsbourg
# concocts to concocted
# actioneffects to effects
# interiors to interior
# vessel to jesse
# moodily to moody
# rainwear to brainer
# apt to rapt
# 1934 to 19
# fleming to filming
# clutchy to clutch
# diatribe to diatribes
# titillation to titillating
# freebie to free
# unedited to edited
# journal to journalism
# clamor to clamorous
# clanging to changing
# nikita to nit
# weaker to weak
# persecutions to perfection
# regime to regimen
# saintly to mainly
# patchouli to patch
# oil to soil
# sums to sum
# unjustified to unsatisfied
# decrying to drying
# emblematic to problematic
# ageism to ages
# afflicting to affecting
# varsity to variety
# all's to hall's
# planning to spanning
# perry to per
# illicit to elicit
# herd to her
# imprisonment to improvement
# nerdy to nervy
# ted to ed
# bundy's to bundy
# justification to mystification
# maniac to mania
# seine to see
# slogs to slog
# artistically' to artistically
# joaquin to joan
# baca to ca
# asay to say
# annoyingly to annoying
# vertigo to averting
# opacity to city
# subsequently to subsequent
# unrecommendable to commendable
# ponderously to ponderous
# mope to mopes
# lightning to lighting
# prize to prizes
# ink to in
# wilts to its
# awhile to while
# rouse to rouses
# topkapi to top
# shayamalan to shyamalan
# fancied to faced
# beatnik to beat
# wim to swim
# wenders to wonders
# downside to downs
# paucity to opacity
# condensation to conversation
# o'clock to clock
# skips to skip
# lobotomized to lobotomy
# preferred to referred
# transfer to transferral
# nettelbeck's to nettelbeck
# heartrending to heartening
# fundamentalists to fundamentals
# relatives to relative
# devotes to devote
# bigoted to bite
# platonic to plato
# chaplin's to chaplin
# monarch to march
# philandering to pandering
# diminishes to undiminished
# tended to ended
# fading to facing
# 1980's to 1980s
# appease to appears
# silliest to silliness
# partway to party
# chao to chaos
# kaige's to kaige
# assistant to distant
# learnt to learn
# marries to carries
# amateurishness to amateurish
# discourages to courage
# regurgitated to regurgitates
# greasiest to greatest
# beached to beach
# grouper to group
# overloads to overload
# sermonizing to sermonize
# dullards to dullard
# reiterates to literate
# willful to will
# evidenced to evidence
# accounting to counting
# texas to tears
# who'd to who'
# universally to universal
# morvern's to morvern
# festooning to stooping
# magically to magical
# significant' to significant
# flatbush to flash
# slavishly to lavishly
# henna to hanna
# ornamentation to orientation
# hamlet to let
# iv to i
# arnold's to arnold'
# opposing to posing
# viewpoints to viewpoint
# toasts to toast
# mailing to failing
# devito to devito's
# payola to pay
# 700 to 70
# hose to those
# stepford to step
# mentality to mental
# mgm to m
# persuasion to person
# prequel to sequel
# ostensibly to possibly
# redford's to records
# imprimatur to immature
# mirthless to ruthless
# solondzian to solondz
# amiability to ability
# personifies to personified
# vibes to vibe
# greased to grease
# ferzan to era
# apartment to apartments
# heresy to here
# contrary to country
# revered to reverse
# vim to i
# dialed to died
# digit to digits
# blackboards to boards
# alliance to allegiance
# culminates to urinates
# bus to us
# temerity to merit
# winding to winning
# majorly to major
# manifestos to manifesto
# amber to chamber
# detracts to detract
# verbinski to veins
# loitering to altering
# nuked to naked
# alex to le
# nc to n
# 17 to 1
# ihops to hop
# hormones to horns
# sledgehammers to sledgehammer
# inquisitions to questions
# 123 to 12
# 950 to 50
# ineffectual to effect
# juggle to jugglers
# juxtapose to pose
# takeoff to take
# sats to sat
# melodramatics to melodramatic
# inflated to inflate
# faintly to faint
# untidy to untidily
# elaborateness to elaborate
# elan to lan
# obscurity to absurdity
# treacherous to teachers
# guillermo to giler
# toro's to toro
# 117 to 11
# wincingly to winningly
# nauseatingly to nauseating
# villians to villains
# introduced to introduce
# sampler to sample
# bumping to bump
# etoiles to ties
# rationale to national
# swimfan's to swimfan
# laurel to lauren
# hardy'n to hardy
# frights to fright
# israelis to israeli
# evenhanded to handed
# installation to distillation
# vinnie to minnie
# spitting to sitting
# hanson to son
# lawyer to lawyers
# investigating to investigation
# jettisons to jettisoned
# meddling to middling
# 79 to 9
# wallow to allow
# debases to base
# grinding to grinning
# lopsided to sided
# reps to re
# delibrately to deliberately
# obtuse to use
# unapproachable to unreachable
# windbags to winds
# drone to done
# inanely to insanely
# cacophony to phony
# prattle to rattled
# again' to again
# collections to collection
# yacht to act
# confrontation to confrontations
# flowed to flow
# hides to hide
# pillage to pillages
# matheson to matches
# puke to uk
# injured to conjured
# hubert's to hubert
# rack to crack
# senior to nor
# fiftysomething to something
# loudly to loud
# videodrome to videodrome'
# individually to individual
# prepubescent to pubescent
# squinting to squint
# glorifying to horrifying
# software to stare
# sluggishly to sluggish
# nap to na
# kilner's to kilmer's
# itching to switching
# tack to tacky
# morphed to morph
# accomplishing to accomplish
# dissatisfied to satisfied
# godawful to awful
# slug to smug
# longs to long
# frisk to risk
# alleys to valley
# snoozy to snooze
# glibly to glib
# eurotrash to trash
# bicycle to cycle
# gazes to gaze
# adjectives to adjective
# inflict to inflicted
# reputations to reputation
# prop to pro
# sourness to sources
# highfalutin to high
# corkscrew to crew
# dumber to dumber'
# begets to gets
# writerdirectorproducer to writerdirector
# portal to port
# selfish to self
# banging to aging
# salesmanship to gamesmanship
# idiot to idiots
# divertingly to diverting
# headbangingly to banging
# respectful to respect
# coffin to off
# fuhgeddaboutit to about
# boil to boils
# egg to e
# buoys to buoy
# hinted to hint
# starred to started
# creaking to creating
# rusty to crusty
# ghosts' to ghosts
# dramatist to dramatics
# blurs to blur
# overreaches to reaches
# spinoffs to spinoff
# stalk'n' to talk
# bradbury to brady
# wachowski to sychowski
# rekindled to rekindle
# kathleen to athlete
# soliah to solid
# upcoming to coming
# sla to slap
# emily to emptily
# fire's to fires
# flaunts to fans
# writhing to writing
# worlds' to worlds
# are' to are
# unoriginality to originality
# wilco's to wilco
# faultlessly to faults
# lethal to lethally
# weapon to weaponry
# knowingness to knowing
# fists to fist
# scatological to ecological
# proctologist to protagonist
# 007 to 7
# abruptly to abrupt
# soppy to sloppy
# regan to regain
# morrissette's to morrissette
# signify to sign
# jovovich to voice
# sanctified to satisfied
# alarmed to armed
# wielding to wedding
# wrenches to wrench
# staple to stale
# programming to program
# pointlessness to pointless
# bonbon to bon
# jaundiced to janice
# cliffsnotes to notes
# cart to art
# outcast to cast
# shed to she
# chipper to ripper
# derails to rails
# 97 to 9
# gels to gel
# plum to plump
# worms to worm
# preprogrammed to program
# guidelines to underlines
# cleverer to clever
# teaching to aching
# timelines to timeless
# russos to russo
# ephemeral to heal
# wrestle to wrestler
# chloroform to form
# handkerchief to chief
# helpfully to helpful
# succinct to suit
# locate to late
# exhaust to exhausted
# spouse to spouses
# consumer to consume
# tonga to ton
# e' to e
# b' to b
# nurse to nurses
# boulevard to board
# soapdish to soap
# glue to glued
# schwartzman to charm
# fond to found
# oafish to fish
# impersonating to impersonation
# relentlessness to relentless
# videogame to vidgame
# sleekly to sleek
# weather to weathered
# frei's to frei
# loosens to loose
# proportion to proportions
# skolnick to slick
# underscores to underscore
# polishing to publishing
# panther to another
# geeky to geek
# waradventure to adventure
# dissolves to doles
# soldier's to soldiers
# spiders to spider
# outrun to out
# motorcycle to motorcycles
# swaggering to staggering
# underwood to underworld
# clique to cliques
# marginalization to imagination
# loom to gloom
# dreamer to dream
# dogwalker to walker
# botch to both
# jobs to job
# benign to benigni
# entirety to entire
# envy to levy
# kazmierski to admirers
# unsuspenseful to suspenseful
# flocking to looking
# spray to pray
# norman to norma
# jewison's to son's
# ultraviolent to violent
# stupider to stupid
# dirk to irk
# 25s to 25
# csokas to soars
# unconnected to connected
# undeveloped to developed
# canter to ante
# rehashing to rehash
# humourless to humorless
# nominal to normal
# arquette to marquee
# cameron to cameo
# mate to mat
# trivial to rival
# provocation to provocations
# obliviousness to obviousness
# dawdles to dawdle
# picture' to picture
# bludgeon to bludgeoning
# unconscious to conscious
# crock to rock
# jackasses to jackass
# convicted to convinced
# felons to feels
# relevancy to irrelevancy
# bothersome to bothers
# earnestly to earnest
# embarrassing to unembarrassing
# newly to new
# automated to automatic
# legends to legend
# trifles to trifle
# ribbing to cribbing
# cheating to eating
# betray to betrayal
# slugs to slug
# yankee to yank
# cheerful to cheerfully
# accordionharmonicabanjo to according
# baggy to bag
# carnival to rival
# stretching to stretch
# rhyme to rye
# qatsi to qatsi'
# oriental to rental
# surfacing to surfing
# instant to instantly
# deaf to def
# gnat to at
# racehorse to horse
# collectible to collective
# 76 to 6
# junctures to futures
# enervated to generated
# hope' to hope
# fundamental to fundamentals
# preamble to ramble
# materializes to materials
# slumber to slummer
# unmolested to molested
# haughtiness to ugliness
# laurels to laurel
# regrettably to forgettably
# clambake to make
# army to arm
# novak's to novak
# reliably to reliable
# freeze to free
# luxury to lux
# boasted to based
# clearer to clear
# furry to fury
# lapdance to dance
# skating to sting
# interspliced to spliced
# russos' to russos
# sketchbook to sketch
# marisa to mars
# tomei to tome
# protagonist's to protagonists
# deficiency to efficiency
# metaphoric to metaphor
# drabness to dress
# endemic to demi
# sabotages to sabotage
# juncture to junctures
# rymer's to rymer
# bloodless to oodles
# spit to spite
# purported to purportedly
# pathologically to pathological
# avenges to avengers
# trippy to trip
# tweedy to weepy
# canning to cunning
# stockbroker to stroke
# repairing to pairing
# yearn to year
# airborne to born
# nude to de
# jesus' to jesus
# showiness to shines
# offsets to offset
# qualls to qual
# indiana to indian
# han to an
# offense to offensive
# wally to wall
# wolodarsky to woody
# jarvis to avis
# coolidge to collide
# stallone's to stallone
# ballpoint to ballot
# columnist to column
# offered to offer
# extraterrestrial to material
# sandrine to andie
# goats to got
# giants' to giants
# tuneless to unless
# title's to titles
# shuns to shu
# hinged to hinge
# crotch to croc
# thinner to inner
# fishes to fish
# grittiest to prettiest
# lanie's to lane's
# harland to heartland
# rosenbaum to rose
# watson to wanton
# unwrapped to wrapped
# recoiling to roiling
# spacey to space
# linda to lina
# fiorentino to foreign
# indigestible to indigestion
# guided to guide
# sharpens to shares
# meaningness to meaningless
# erase to ease
# repeats to eats
# deconstruct to construct
# daydreaming to dreaming
# yuks to yu
# vaulting to acting
# stoned to stone
# veiled to veil
# honed to phoned
# airport to port
# security to insecurity
# unmoved to moved
# repackaged to prepackaged
# disclosure to closure
# tourist to tourists
# mississippi to miss
# scriptwriter's to scriptwriters
# mods to mod
# rockers to rocks
# miscasts to miscast
# estate to state
# danilo to dani
# donati's to nair's
# designs to design
# dante to ante
# spinotti's to spots
# insisted to instead
# slipshod to slips
# hewitt's to hewitt
# gowns to own
# comebacks to comeback
# melville to melville's
# tuna to na
# hoppy to choppy
# penis to pen
# breast to breasts
# profit to profits
# gilligan's to gilliam's
# jags to as
# gee to geek
# moot to mo
# hysterical to hysteria
# disquisition to inquisitions
# hooey to hey
# desplechin to delhi
# scent to cent
# farmer's to arm's
# battling to batting
# depersonalization to personality
# serry to serry's
# unwittingly to unremittingly
# festive to fest
# levant to relevant
# skates to kate
# pausing to using
# bows to bow
# poodle to pool
# heaviest to heist
# noodle to oodles
# perpetrators to perpetrated
# dingoes to goes
# bold' to bold
# wilt to wilts
# sprinklings to sparkling
# belushi's to welsh's
# likableness to likable
# gulps to gulp
# huggy to hug
# deflates to deflated
# spiritedness to spirited
# numbs to numb
# dampens to damn
# townsend to owned
# egyptian to egypt
# demigod to demi
# integral to internal
# inspirational' to inspirational
# uplifting' to uplifting
# fog to flog
# ashes to she
# sings to sing
# completed to complete
# abandons to abandon
# pretense to pretends
# waltzes to waltz
# parodies to parodied
# perplexed to peopled
# elegiacally to elegiac
# ryanovich to ryan
# pegs to pg
# middles to middle
# ja to a
# rule to rules
# kurupt to kurt
# benefitted to benefited
# transplanted to transplant
# groans to groan
# scrappy to crappy
# elementary to element
# reduction to reductions
# water' to water
# slacker to slackers
# deficient to efficient
# stalk to talk
# rams to ram
# gob to go
# pasteurized to plastered
# ditties to ties
# retch to stretch
# crème to crime
# brûlée to be
# multifaceted to ultimate
# 1954 to 19
# shelved to shelves
# earthbound to around
# dank to dan
# melodramacharacter to dramacharacter
# stinky to stink
# subservient to subsequent
# bond's to bonds
# brandishing to ravishing
# financial to facial
# extortion to exploration
# glacier to uglier
# touchy to touch
# feely to feel
# mindedness to sidedness
# deconstructionist to deconstruction
# philosopher to philosophers
# vanishes to vanished
# ugliest to lies
# colonialist to colonialism
# mute to muted
# trolls to rolls
# met to me
# sentences to sentence
# splashes to splash
# subjecting to subject
# resnick to nick
# cabin to cabins
# pound to pond
# insider's to insiders
# lingo to lin
# brotherly to brother
# petroni to petri
# akasha to ash
# coeducational to educational
# fraternity to rarity
# kappa to pa
# rho to ho
# alpha to ralph
# phi to hi
# travels to travel
# outrunning to running
# fireball to fireballs
# body' to body
# quiver to ver
# ineptitudes to ineptitude
# slots to lots
# spencer to specter
# tracy to racy
# bottomless to bottomlessly
# charity to clarity
# clink to link
# frenzied to fried
# click to clicks
# prospective to perspective
# embroiled to embroils
# yu's to yu
# stupor to por
# elapse to else
# slashers to slasher
# boiler to boil
# murdering to murder
# 1978 to 19
# interlocking to introducing
# scandinavian to canadian
# settlers to settles
# 18th to 8th
# sailboaters to sailor
# ganesh to ganesh's
# midlevel to level
# metaphorically to metaphorical
# dumbest to best
# mysticism to mystic
# mystifying to satisfying
# novella to novel
# fied to field
# schooling to school
# murkiest to murk
# boyd to boy
# apallingly to appalling
# thereof to there
# portable to portal
# stupidly to stupid
# migraine to grain
# spoon to soon
# feeding to feeling
# arrested to arrest
# baller to ball
# 1982's to 1982
# forgetting to getting
# retain to retains
# lulling to pulling
# allergy to gallery
# unavailable to available
# ushers to usher
# marathon to marathons
# influx to flux
# liquid to fluid
# gallagher to gallery
# dishonor to honor
# disconnected to connected
# somnolent to some
# mummified to unified
# candle to candles
# hallways to always
# windup to wind
# dislike to like
# mating to acting
# leavitt to levity
# noxious to obnoxious
# louder to loud
# ponytail to pony
# squandered to squander
# irwins to irwin
# criminally to criminal
# thirsty to thirst
# honey to phoney
# deli to del
# excrescence to presence
# consumption to consuming
# belonged to belong
# beta to bet
# delta to del
# predator to predators
# germany to german
# ahola's to ahola
# expulsion to explosion
# crushes to crush
# crosscuts to cross
# shun to shu
# fatigues to figures
# gi to i
# clunk to clunky
# overtime to everytime
# error to terror
# mirror to minor
# communism to community
# prompting to opting
# muffled to ruffle
# costumey to costume
# passivity to passive
# ploy to lo
# kegger to keg
# sounded to sound
# pitcher to pitch
# thrall to enthrall
# contents to content
# investing to inventing
# emi to semi
# 1992 to 19
# malfitano to mafia
# domingo to doing
# filmmaking' to filmmaking
# like' to like
# true' to true
# commonly to common
# hire to hired
# mismatched to matched
# asinine to nine
# twist' to twist
# problems' to problems
# solved to resolved
# kvetch to sketch
# diluted to dilutes
# gravitas to gravity
# placeholder to placed
# ergo to ego
# unpicked to picked
# vine to vin
# afforded to afford
# springsteen's to springs
# asbury to buy
# mechanism to mechanisms
# avoided to avoid
# swamped to same
# conciliatory to obligatory
# seasons to season
# rhetorical to rhetoric
# 401 to 40
# heaviness to heaviest
# synchronized to sized
# swimmer to wimmer
# wool to woo
# wetsuit to suit
# faking to king
# mellow to mell
# carbon to cuaron
# jackets to jacket
# intends to tends
# mangle to angle
# slowtime to showtime
# voyages to voyage
# limping to lisping
# survive' to survive
# chip to hip
# microwaves to waves
# leftover to leftovers
# basted to based
# gravy to gray
# distributors to struts
# comicthriller to thriller
# aboul to about
# finder to find
# bull's to bull
# twentieth to teeth
# legitimate to ultimate
# extensively to extensive
# resolve to resolved
# woods' to woods
# bolly to boll
# saldanha to dana
# adherence to adhere
# knot to not
# swap to sap
# depart to departs
# montias to months
# montied to mounted
# pandered to pander
# heartless to artless
# ratner to rather
# elmore to more
# sen's to sense
# hapless to shapeless
# syndrome to some
# sushi to us
# swamp to swap
# doubled to double
# tel to tell
# aviv to iv
# rome to rom
# threaten to threatens
# upstage to upstaged
# warpath to wrath
# devilish to devils
# pretentiously to pretentious
# overpower to overpowered
# bong to bon
# downing to doing
# alcoholic to cool
# beverage to average
# rabbits to rabbit
# brimful to brim
# portion to portions
# respected to respect
# navajos to naval
# specious to precious
# hoo to hook
# fictitious to fictions
# trailers to trailer
# scorns to scorn
# strainingly to straining
# orphan to orphans'
# wandered to wander
# gantzes' to gantz
# ballhaus to ballast
# spurts to puts
# baz to ba
# luhrmann to mann
# causing to using
# smelly to smell
# despising to dressing
# casually to casual
# unceasing to casting
# whistles to whistle
# bells to tells
# suffocated to suffocate
# munchausen to munch
# proxy to pro
# mum to um
# punish to push
# adore to adored
# pancakes to paces
# sand'n' to sand
# sandal to scandal
# thuggery to huggers
# defunct to deft
# cleopatra to clear
# 2525 to 25
# bundle to bungle
# diffuses to fuses
# uberviolence to violence
# clericks to clicks
# smoothes to smooth
# lent to let
# atonal to tonal
# demonizes to demons
# gifting to lifting
# vomit to mit
# patter to platter
# remainder to reminder
# jed to ed
# violins to violinist
# kate's to kate
# unlistenable to unstable
# lowering to flowering
# booming to booking
# bass to basis
# linguistic to inuit
# fumbling to bumbling
# macy to may
# gray's to gray
# whispers to whimper
# cigarette to care
# roisterous to boisterous
# here' to here
# christophe to christopher
# honoré to honor
# similarities to similar
# gymkata to mat
# howie to how
# long's to ong's
# firestorm to fires
# fingernails to fingers
# instinctively to distinctive
# crawled to scrawled
# disquiet to quiet
# christians to christian
# reductionist to reductions
# feelgood to flood
# omnipotent to potent
# affronted to front
# secularists to secular
# antlers to banter
# shorn to short
# researchers to research
# letters to letter
# lite to lit
# obsolete to sole
# boat's to boats
# malediction to diction
# grapple to apple
# irrevocably to irrevocable
# disintegration to disintegrating
# flute to fluke
# meltdown to letdown
# stupidest to stupid
# boast to boasts
# violates to violated
# throated to throat
# staleness to sameness
# admission's to admission
# slummy to scummy
# comedythriller to comicthriller
# nrelentingly to unrelentingly
# No. new words: 1933

# %%
with open(f"{resource_folder}/datasets/{dataset_folder}/split/{dataset_name}-test-new-words.json", "w") as f :
    f.write(json.dumps(dataset.new_words, indent=4))

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    f"{resource_folder}/output/{dataset_name}-train/checkpoint-1500",
    num_labels=dataset.n_classes
)
# Out:
# c:\Users\T-Gamer\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_utils.py:133: UserWarning: Failed to initialize NumPy: module compiled against API version 0x10 but this version of numpy is 0xf (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:68.)
#   t = torch.tensor([], dtype=storage.dtype, device=storage._untyped().device)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(16176, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
sentence_ids, predictions = [], []
n_batches = math.ceil(len(dataset) / batch_size)
for batch in range(n_batches) :
    print("Batch", batch + 1, "of", n_batches)
    input_dict = dataset[batch * batch_size : (batch + 1) * batch_size]
    preds = model.forward(input_ids=input_dict['input_ids'], attention_mask=input_dict['attention_mask'])
    sentence_ids += input_dict['sentence_ids']
    predictions  += [float(logit[0]) for logit in preds['logits']]
prediction_column = pd.Series(predictions, index=sentence_ids, name="predictions")
# Out:
# Batch 1 of 139
# Batch 2 of 139
# Batch 3 of 139
# Batch 4 of 139
# Batch 5 of 139
# Batch 6 of 139
# Batch 7 of 139
# Batch 8 of 139
# Batch 9 of 139
# Batch 10 of 139
# Batch 11 of 139
# Batch 12 of 139
# Batch 13 of 139
# Batch 14 of 139
# Batch 15 of 139
# Batch 16 of 139
# Batch 17 of 139
# Batch 18 of 139
# Batch 19 of 139
# Batch 20 of 139
# Batch 21 of 139
# Batch 22 of 139
# Batch 23 of 139
# Batch 24 of 139
# Batch 25 of 139
# Batch 26 of 139
# Batch 27 of 139
# Batch 28 of 139
# Batch 29 of 139
# Batch 30 of 139
# Batch 31 of 139
# Batch 32 of 139
# Batch 33 of 139
# Batch 34 of 139
# Batch 35 of 139
# Batch 36 of 139
# Batch 37 of 139
# Batch 38 of 139
# Batch 39 of 139
# Batch 40 of 139
# Batch 41 of 139
# Batch 42 of 139
# Batch 43 of 139
# Batch 44 of 139
# Batch 45 of 139
# Batch 46 of 139
# Batch 47 of 139
# Batch 48 of 139
# Batch 49 of 139
# Batch 50 of 139
# Batch 51 of 139
# Batch 52 of 139
# Batch 53 of 139
# Batch 54 of 139
# Batch 55 of 139
# Batch 56 of 139
# Batch 57 of 139
# Batch 58 of 139
# Batch 59 of 139
# Batch 60 of 139
# Batch 61 of 139
# Batch 62 of 139
# Batch 63 of 139
# Batch 64 of 139
# Batch 65 of 139
# Batch 66 of 139
# Batch 67 of 139
# Batch 68 of 139
# Batch 69 of 139
# Batch 70 of 139
# Batch 71 of 139
# Batch 72 of 139
# Batch 73 of 139
# Batch 74 of 139
# Batch 75 of 139
# Batch 76 of 139
# Batch 77 of 139
# Batch 78 of 139
# Batch 79 of 139
# Batch 80 of 139
# Batch 81 of 139
# Batch 82 of 139
# Batch 83 of 139
# Batch 84 of 139
# Batch 85 of 139
# Batch 86 of 139
# Batch 87 of 139
# Batch 88 of 139
# Batch 89 of 139
# Batch 90 of 139
# Batch 91 of 139
# Batch 92 of 139
# Batch 93 of 139
# Batch 94 of 139
# Batch 95 of 139
# Batch 96 of 139
# Batch 97 of 139
# Batch 98 of 139
# Batch 99 of 139
# Batch 100 of 139
# Batch 101 of 139
# Batch 102 of 139
# Batch 103 of 139
# Batch 104 of 139
# Batch 105 of 139
# Batch 106 of 139
# Batch 107 of 139
# Batch 108 of 139
# Batch 109 of 139
# Batch 110 of 139
# Batch 111 of 139
# Batch 112 of 139
# Batch 113 of 139
# Batch 114 of 139
# Batch 115 of 139
# Batch 116 of 139
# Batch 117 of 139
# Batch 118 of 139
# Batch 119 of 139
# Batch 120 of 139
# Batch 121 of 139
# Batch 122 of 139
# Batch 123 of 139
# Batch 124 of 139
# Batch 125 of 139
# Batch 126 of 139
# Batch 127 of 139
# Batch 128 of 139
# Batch 129 of 139
# Batch 130 of 139
# Batch 131 of 139
# Batch 132 of 139
# Batch 133 of 139
# Batch 134 of 139
# Batch 135 of 139
# Batch 136 of 139
# Batch 137 of 139
# Batch 138 of 139
# Batch 139 of 139

# %%
dataset_with_preds_df = pd.concat([dataset_df, prediction_column], axis=1)

# %%
if not os.path.exists(output_dir) :
    os.makedirs(output_dir)
dataset_with_preds_df.to_csv(f"{output_dir}/Predictions.csv")

# %%
dataset_with_preds_df
# Out:
#                                                     text  phrase_id     class  \
# 3                 <start> effective but too tepid biopic      13995  0.513890
# 4      <start> if you sometimes like to go to the mov...      14123  0.736110
# 5      <start> emerges as something rare an issue mov...      13999  0.861110
# 6      <start> the film provides some great insight i...      14498  0.597220
# 7      <start> offers that rare combination of entert...      14351  0.833330
# ...                                                  ...        ...       ...
# 11621              <start> an imaginative comedythriller      13851  0.777780
# 11623                      <start> a rare beautiful film      18182  0.916670
# 11626               <start> an hilarious romantic comedy      23211  0.888890
# 11628              <start> never sinks into exploitation      26177  0.625000
# 11798                      <start> u nrelentingly stupid     141831  0.069444
#
#        predictions
# 3         0.356394
# 4         0.739910
# 5         0.601264
# 6         0.697847
# 7         0.775601
# ...            ...
# 11621     0.768816
# 11623     0.827225
# 11626     0.738332
# 11628     0.232675
# 11798     0.201296
#
# [2210 rows x 4 columns]

# %%
hits, total = 0, 0
for _, row in dataset_with_preds_df.iterrows() :
    total += 1
    pred  = row["predictions"] >= .5
    label = row["class"]       >= .5
    if pred == label : 
        hits += 1
accuracy = hits / total
accuracy
# Out:
# 0.7330316742081447

# %%
hits, total = 0, 0
for _, row in dataset_with_preds_df.iterrows() :
    total += 1
    pred  = row["predictions"]
    label = row["class"]
    diff = label - pred
    hits += abs(diff)
avg_dev = hits / total
avg_dev
# Out:
# 0.1626037349799219

# %%
true_positives, true_negatives, false_positives, false_negatives = 0, 0, 0, 0
for _, row in dataset_with_preds_df.iterrows() :
    pred  = row["predictions"] >= .5
    label = row["class"]       >= .5
    if pred == label :
        if pred :
            true_positives  += 1
        else :
            true_negatives  += 1
    else :
        if pred :
            false_positives += 1
        else :
            false_negatives += 1
print(true_positives, true_negatives, false_positives, false_negatives)
# Out:
# 694 926 173 417

# %%
precision = true_positives / (true_positives + false_positives)
precision
# Out:
# 0.8004613610149942

# %%
recall = true_positives / (true_positives + false_negatives)
recall
# Out:
# 0.6246624662466247

# %%
f1 = (2 * precision * recall) / (precision + recall)
f1
# Out:
# 0.7017189079878666
