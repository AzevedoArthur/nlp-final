# %%
import numpy as np
import pandas as pd
import os, json, math

os.getcwd()
# Out:
# 'c:\\Users\\T-Gamer\\Documents\\SideDrive\\UFMA\\2022.1\\Topicos Especiais (NLP)\\Exercicios\\Trabalho Final\\Implementação\\source'

# %%
import torch

# %%
from transformers import AutoModelForSequenceClassification

# %%
def levenshtein(source:str, target:str) -> int :
    n = len(source)
    m = len(target)
    
    D = np.zeros((n + 1, m + 1), dtype=int)
    for i in range(1, n + 1) :
        D[i][0] = D[i - 1][0] + 1
    for j in range(1, m + 1) :
        D[0][j] = D[0][j - 1] + 1

    subst_cost = lambda x, y : 0 if x == y else 4
    for i in range(1, n + 1) :
        for j in range(1, m + 1) :
            D[i][j] = min([D[i - 1][j    ] + 1,
                           D[i - 1][j - 1] + subst_cost(source[i - 1], target[j - 1]),
                           D[i    ][j - 1] + 1])
    return D[n][m]
def distance(source:str, target:str) -> float :
    lev = levenshtein(source, target)
    if source in target or target in source : lev = lev - .5 
    return lev

# %%
class Dataset(torch.utils.data.Dataset) :
    def __init__(self, 
                 dataframe:pd.DataFrame, 
                 vocabulario:list[str],
                 translation_dict:dict[str,str]=None,
                 max_length:int=512,
                 text_column:str='text',
                 label_column:str='class',
                 n_classes:int=1) :
        self.dataframe = dataframe
        self.vocabulario_original = vocabulario
        self.vocabulario_dict = {word : i for i, word in enumerate(self.vocabulario_original)}
        
        vocabulario_real = []
        for txt in list(self.dataframe[text_column]) :
            vocabulario_real += txt.split()
        vocabulario_real = list(pd.Series(vocabulario_real).unique())
        
        if translation_dict is None :
            self.new_words = {}
        else :
            self.new_words = translation_dict
            for new, translation in translation_dict.items() :
                self.vocabulario_dict[new] = self.vocabulario_dict[translation]
        
        for tkn in vocabulario_real :
            if not tkn in self.vocabulario_dict.keys() :
                voc_sort = list(self.vocabulario_dict.keys())
                voc_sort.sort(key=lambda x : distance(tkn, x))
                print(tkn, "to", voc_sort[0])
                self.new_words[tkn] = voc_sort[0]
                self.vocabulario_dict[tkn] = self.vocabulario_dict[voc_sort[0]]
        print("No. new words:", len(self.new_words))
        
        self.max_length = max_length
        self.text_column = text_column
        self.label_column = label_column
        self.n_classes = n_classes
    def __len__(self) :
        return self.dataframe.shape[0]
    def text_processing(self, text:str) :
        tokenlist = text.split()
        
        sequence = []
        for token in tokenlist :
            sequence.append(self.vocabulario_dict[token] + 1)

        mask = [1 for _ in range(len(sequence))]
        if len(sequence) > self.max_length :
            sequence = sequence[ : self.max_length]
            mask = mask[ : self.max_length]
        else :
            padding = [0 for _ in range(self.max_length - len(sequence))]
            sequence = sequence + padding
            mask = mask + padding
        
        return sequence, mask

    def __getitem__(self, index) :
        if type(index) == int :
            sequence, mask = self.text_processing(self.dataframe.iloc[index][self.text_column])
            label = self.dataframe.iloc[index][self.label_column]
            label = [label]
            label = torch.tensor(label)
            return {
                    'sentence_ids'      : self.dataframe.iloc[index].name,
                    'input_ids'      : torch.tensor(sequence),
                    'attention_mask' : torch.tensor(mask),
                    'labels'         : label
                }
        elif type(index) == slice :
            start = index.start
            if start == None : start = 0
            stop = index.stop
            if stop == None or stop > len(self) : stop = len(self)
            
            sentence_ids = []
            input_ids, attention_mask, labels = [], [], []
            for i in range(start, stop) :
                item = self[i]
                sentence_ids.append(item["sentence_ids"])
                input_ids.append(item["input_ids"])
                attention_mask.append(item["attention_mask"])
                labels.append(item["labels"])

            input_ids_tensor = torch.tensor([list(sentence) for sentence in input_ids])
            attention_mask_tensor = torch.tensor([list(sentence) for sentence in attention_mask])
            labels_tensor = torch.tensor([list(sentence) for sentence in labels])
            
            return {'sentence_ids'   : sentence_ids,
                    'input_ids'      : input_ids_tensor,
                    'attention_mask' : attention_mask_tensor,
                    'labels'         : labels_tensor}
        else :
            raise IndexError()

# %%
# Para dataset simples, sem folding
# Args
dataset_folder = "../resources/datasets/StanfordSentimentTreebank"
dataset_name   = "SST2Processed"
dataset_split   = "test"
batch_size = 16

# %%
# Exec
embeddings_df = pd.read_csv(f"{dataset_folder}/embeddings/{dataset_name}.csv", index_col=0)
dataset_df    = pd.read_csv(f"{dataset_folder}/split/{dataset_name}-{dataset_split}.csv",      index_col=0)

output_dir    = f"../resources/output/{dataset_name}-Eval"

with open("../resources/datasets/StanfordSentimentTreebank/split/test-new-words.json", "r") as f :
    new_words = json.loads(f.read())

dataset = Dataset(dataset_df, embeddings_df.index.tolist(), new_words)
# Out:
# showed to show
# curl to curler
# fed to ed
# ponders to ponder
# enrapturing to featuring
# tempt to attempt
# inscrutable to suitable
# bleakly to bleak
# professionalism to professional
# latent to late
# gangsta to angst
# shook to hook
# rattled to rated
# deceptive to deceptively
# grimness to dimness
# fatalist to fatalism
# worldview to world
# roadside to broadside
# cafe to ca
# permeate to permeates
# cartoonlike to cartoon
# magnet to magnetic
# fuller to full
# chanting to enchanting
# braided to aided
# wipe to swipe
# jeweled to welled
# bead to bad
# lacerating to lactating
# cheesiness to cheesiest
# johnson to john
# orchestrates to orchestrated
# siberian to brian
# sheep to see
# parka to park
# everytime to every
# uncontrolled to controlled
# farther to father
# quietness to quiet
# buildup to build
# maverick to eric
# shading to shaking
# coloring to color
# treebeard to beard
# gollum to glum
# aberration to narration
# originally to original
# isle to aisle
# misogynistic to misogynist
# tok to ok
# orchestrate to orchestrated
# overpraised to praised
# catchy to catch
# spycraft to craft
# lynching to synching
# meeropol to metropolis
# anthropologically to anthropology
# suburbia to suburban
# interstitial to initial
# disappear to disappears
# vertiginous to serious
# ember to member
# dormant to dorm
# calcified to life
# chronic to chronicle
# hemmingway to highway
# accelerated to celebrated
# piesiewicz to pie
# veronique to verne
# sl to s
# pabst to past
# ribbon to bon
# du to u
# sarcasm to sara
# andrew to drew
# quizzical to qual
# syncopated to coated
# mimicking to mimic
# puffery to puff
# obviation to obligation
# erasing to raising
# recasts to cast
# gambol to gamble
# fluidly to fluid
# deconstructing to deconstruction
# doubtless to double
# blessing to bless
# responsive to response
# thru to th
# strap to trap
# frontier to front
# logistical to logistically
# schweiger to schweig
# steak to streak
# minefield to field
# gorefests to gorefest
# coarseness to coarse
# quill to ill
# cent to nt
# stump to sum
# speech to pee
# hog to ho
# punishing to pushing
# plausibility to implausibility
# partially to partly
# minty to monty
# underwritten to written
# fooled to fool
# prize to price
# rambunctious to ambitious
# happiest to happens
# commodity to community
# homespun to home
# mule to le
# skinner to inner
# seaworthy to worthy
# fantastical to fantastic
# sock to shock
# makmalbaf to makhmalbaf
# kurdish to dish
# borderland to border
# chunk to hunk
# pinch to pin
# tartness to artless
# tribulation to contribution
# willams to williams
# ebb to b
# deposit to posit
# freeway to free
# exhilarate to exhilarating
# beanie to bean
# escalating to relating
# admired to admire
# latifah to latin
# flaunting to haunting
# diverted to diver
# lightens to lighten
# chimpanzee to chimp
# surgical to serial
# questing to question
# racked to cracked
# loathing to floating
# genet to gene
# rechy to reach
# fassbinder to aside
# nocturnal to natural
# goya to go
# badge to bad
# permutation to reputation
# crystalline to crystallize
# implicit to simplicity
# americana to american
# fictionalize to fictional
# uncommercial to commercial
# grasped to grasp
# composing to posing
# nonthreatening to threatening
# offs to offset
# fastidiousness to seriousness
# ellefsen to ellen
# magnified to magnifique
# vex to ve
# petin to pet
# penetrates to generates
# tantalizing to amazing
# provocatuers to provocateur
# aroused to used
# mideast to midst
# perceptively to perceptive
# jirí to jr
# hubac to ub
# silberstein to silbersteins
# additional to addition
# ribald to bald
# shapelessly to shapeless
# gratifying to gratify
# appraisal to april
# torpor to toro
# intently to intent
# regime to regimen
# figurative to figure
# port to sport
# dock to doc
# unloading to leading
# testify to test
# comparative to comparatively
# inhabited to inhabit
# incendiary to diary
# venomous to enormous
# bigotry to gory
# theocracy to theory
# wrench to french
# antithesis to thesis
# dazzlingly to dazzling
# münch to munch
# overindulgence to indulgence
# deteriorating to deterioration
# croc to rock
# disrupts to distorts
# specialty to special
# endearingly to endearing
# soviet to movie
# russia to russian
# bishop to shop
# standouts to standout
# bastion to action
# ikea to ke
# blurred to lured
# remembers to remember
# transferral to feral
# sanded to sand
# microcosm to croc
# dabbling to bling
# creamy to cream
# battista to artist
# aspiring to spring
# directress to directs
# breezily to breezy
# apolitical to political
# gawk to gawky
# applaud to applauded
# wallpaper to paper
# hu to u
# glint to lint
# raja to rama
# enthuse to thus
# andersson to anderson
# rigorous to rigor
# distancing to dancing
# movingly to moving
# magimel to magi
# dennis to denis
# weakened to weaned
# supportive to support
# valedictory to victory
# shard to hard
# gyro to go
# farrell to farrelly
# foil to fil
# colonel to clone
# conditioned to condition
# saucer to sucker
# downy to down
# cheeked to cheek
# moppet to mope
# empathetic to pathetic
# bennett to bent
# descent to decent
# breakup to break
# wordplay to worldly
# preference to reference
# indomitable to inimitable
# ostentatious to tenacious
# randy to ran
# figuratively to figurative
# lucía to luc
# arousing to rousing
# rhythmic to rhythm
# adulthood to adult
# fraught to caught
# addessi to address
# beatrice to beat
# fidelity to infidelity
# melding to mending
# reflecting to reflection
# heartbeat to heartbreak
# heartedly to hearted
# horrifically to horrific
# spunk to punk
# gruelling to grueling
# rockwell to stockwell
# vastness to vanessa
# comprehensive to comprehensible
# beaut to beauty
# bundy to und
# reilly to really
# octopus to oops
# deceivingly to receiving
# retrospect to retrospective
# likability to liability
# increment to vincent
# camouflaged to camouflage
# adoration to duration
# hogwarts to hogwash
# mischief to chief
# aquatic to tic
# baja to ba
# peninsula to insular
# symmetry to summery
# patois to pathos
# tossing to toss
# bellini to elli
# mullinski to mull
# compact to pact
# breeze to breezy
# sardine to sade
# cried to crime
# relocation to location
# displayed to display
# inexperience to inexperienced
# flotsam to flam
# unearthed to unearth
# taker to take
# sandwiched to sandwich
# rending to ending
# elliott to elli
# connects to connect
# ranging to raging
# gather to rather
# lavventura to ventura
# repulsion to revulsion
# congeals to conceal
# tingle to tinge
# anytime to daytime
# narcotizing to acting
# biennial to genial
# ensnaring to endearing
# indicates to indicate
# oblivion to oblivious
# examined to examine
# intuitively to punitively
# squalor to qual
# bared to bare
# confronted to confront
# stealth to steal
# precollegiate to collegiate
# liberated to literate
# hogan to hog
# headlong to along
# timeframe to frame
# peterspider to spider
# cozy to coy
# spun to pun
# afresh to fresh
# arouse to aroused
# unknowing to knowing
# resolute to resolutely
# nakedness to naked
# preciously to precious
# interwoven to intern
# stimulates to stimulate
# unobtrusively to intrusive
# plentiful to pitiful
# manipulate to manipulative
# saturation to situation
# bombing to bomb
# divining to driving
# confirmation to configuration
# unelected to neglected
# incurious to curious
# uncharismatic to charismatic
# overgrown to grown
# whiplash to whip
# glad to lad
# stopping to topping
# unmentioned to mentioned
# yimou to mo
# amalgamating to amalgam
# relax to relaxed
# undoubted to undoubtedly
# miraculously to miraculous
# excessive to excessively
# sparklingly to sparkling
# raiser to raise
# bonehead to head
# deciding to ending
# affirmation to affirmational
# deedbad to deed
# sinner to inner
# symmetrical to serial
# unaccustomed to accused
# shy to sy
# artifact to artefact
# arena to area
# barrett to brett
# browning to drowning
# hmm to hmmm
# nurturing to turning
# gauzy to guy
# dithering to adhering
# zig to zing
# zag to z
# projected to project
# dreyfus to refuse
# pattern to platter
# swashbuckling to swashbuckler
# fatality to fatalist
# classism to classicism
# ignorance to ignore
# sympathetically to pathetically
# personifying to personified
# purest to rest
# intimidating to imitating
# horrorthriller to thriller
# intertwined to intentioned
# blobby to lobby
# superlarge to large
# changer to change
# evaluation to devaluation
# guidance to dance
# invade to invader
# abundance to sundance
# fanatically to fanatical
# fetishized to fetish
# idiosyncrasy to idiosyncratic
# monastic to moralistic
# majesty to majestic
# slipper to slippery
# incarnates to innate
# prophetic to prophet
# exacting to acting
# patronized to parodied
# incandescent to indecent
# stupendous to spends
# unquestionably to questionable
# bedouin to bed
# softest to softens
# revolt to revolting
# cuff to buff
# stylishness to stylish
# gunning to running
# preschool to school
# humored to humor
# charmingly to charming
# depicting to depiction
# bola to la
# peeved to pee
# weigh to weight
# loosey to loose
# goosey to goose
# destinees to destin
# sheen to seen
# bedevils to devil
# teamwork to work
# molony to moon
# simon to simone
# parisian to partisan
# rebirth to bit
# ensnared to ensnare
# almodóvar to almodovar
# ferocious to serious
# gosh to go
# courting to outing
# actualization to realization
# continental to continent
# divide to divided
# owner to downer
# dominatrix to dominate
# characterizing to characterization
# tailored to tailor
# knot to nt
# scuzbag to cuba
# delicacy to delay
# surpassed to passed
# empress to press
# leoni to leon
# ellie to elli
# recapturing to capturing
# locked to clocked
# mold to old
# herek to cheek
# bottle to battle
# hornby to horn
# idoosyncratic to idiosyncratic
# terrain to train
# sappier to spider
# assuredness to assured
# pigeonhole to hole
# resisting to resist
# reinforces to enforced
# elmer to helmer
# bernstein to burstein
# melodic to meld
# inch to inc
# shambling to rambling
# custom to customer
# belated to bloated
# bumpy to bump
# lap to slap
# ta to tap
# carion to caring
# dyspeptic to septic
# mirth to smith
# frisky to risky
# exporing to exploring
# marketplace to replace
# amusingly to amusing
# ross to cross
# entrancing to enhancing
# darn to dan
# smarty to smart
# aura to laura
# balletic to ballet
# agreeable to agreeably
# epoch to epic
# sampling to smiling
# inequity to inquiry
# immorality to morality
# misperception to perception
# appalled to apple
# shinya to shiny
# tsukamoto to sum
# iron to irony
# benoit to bent
# heaving to leaving
# puccini to pun
# fandango to danang
# abbas to abbass
# befuddlement to element
# marvellous to marvelous
# earthshaking to shaking
# fluctuating to lactating
# humanitarian to humanity
# unlucky to lucky
# cassette to asset
# def to de
# leppard to lead
# pyromania to roman
# fandom to random
# combo to com
# closeness to looseness
# unreality to reality
# hoop to whoop
# plump to lump
# fulsome to fuse
# reinforced to enforced
# rookie to cookie
# quantum to quaint
# picking to kicking
# pothole to porthole
# befall to fall
# reviewing to viewing
# obscurity to absurdity
# miniscule to mini
# bleep to lee
# oiled to boiled
# upholstered to bolstered
# sickness to slickness
# rara to ararat
# avis to davis
# articulated to articulate
# burdette to bette
# utmost to moist
# economy to economic
# samantha to santa
# viewfinder to viewer
# cadness to sadness
# candidly to candid
# westfeldt to west
# juergensen to urge
# crit to critic
# shagster to shatner
# casey to case
# kasem to em
# furnished to finished
# amongst to among
# foreboding to reading
# adroitly to adroit
# madame to adam
# refer to prefer
# spate to spat
# translates to translate
# hors to horse
# doeuvre to oeuvre
# filmic to film
# sizzling to sibling
# reconsideration to consideration
# fountainhead to fontaine
# wager to age
# dingy to ing
# backroom to broom
# leisurely to surely
# discontented to discontent
# koyaanisqatsi to qatsi
# powaqqatsi to qatsi
# inventively to inventive
# extols to ethos
# comradeship to crash
# spunky to spunk
# retribution to tribulation
# modulated to muted
# kaputschnik to push
# despondent to dependent
# renown to reno
# dolgin to dog
# eagerly to eager
# infecting to affecting
# pasadena to sade
# hooter to hoot
# mistaking to taking
# grass to ass
# melrose to rose
# erika to era
# mod to mo
# kickass to kick
# beau to beaut
# travil to travail
# nenette to nanette
# boni to bon
# perverted to perverse
# simplest to simple
# flaky to fly
# bizarrely to bizarre
# splittingly to spittingly
# piper to pipe
# perabo to era
# magnificence to magnificent
# chorus to chou
# winsome to wise
# premier to premise
# sarcastic to arctic
# shield to held
# outta to out
# tierney to tier
# choking to chong
# engulfing to beguiling
# allying to lying
# resonates to resonate
# comparable to parable
# renoir to reno
# resent to present
# professes to process
# giddily to giddy
# francophile to franchise
# knowingly to knowing
# hedonist to hedonistic
# aborbing to absorbing
# arguable to arguably
# hallucination to hallucinatory
# monkeyfun to monkey
# bounty to bout
# petersburg to peter
# bluntly to blunt
# newold to new
# exigency to agency
# adorned to adored
# pleasurably to pleasurable
# jacked to jack
# philibert to liberty
# observes to observe
# schoolhouse to school
# truffle to ruffle
# dainty to day
# psychopathy to psychopathic
# ecologically to ecological
# unconventionally to unconventional
# venerable to vulnerable
# reheated to heated
# weeping to sweeping
# relaxing to relating
# lauren to laurence
# puzzlement to puzzle
# symbolizes to symbolism
# alzheimer to dahmer
# interacting to interaction
# endedness to tenderness
# barbecue to barb
# mindedly to minded
# presuppose to suppose
# zealous to zealously
# nuttiness to business
# antagonist to antagonism
# impartiality to martial
# atom to tom
# broached to broach
# nonagenarian to mongering
# boldness to badness
# pentecostal to pedestal
# dallas to ala
# warthog to warmth
# hyperbole to hyperbolic
# bravely to brave
# delve to del
# peddled to padded
# jakob to job
# allegorical to allegory
# quench to queen
# josef to jose
# bierbichler to richer
# monica to moronic
# bleibtreu to bite
# helene to lee
# weigel to weil
# andy to candy
# richest to chest
# ricci to ci
# thwart to tart
# nathan to jonathan
# crummles to rule
# bustingly to busting
# weakest to weak
# thinnest to thinness
# sleepy to sleep
# declares to declared
# expressed to express
# bend to end
# architectural to architecture
# connecting to connection
# historian to historical
# viciously to vicious
# griping to gripping
# garry to gary
# shandling to handling
# unsettlingly to unsettling
# deceitful to deceit
# idealistically to realistically
# selfless to useless
# coldly to cold
# unselfconscious to conscious
# invariably to inevitably
# cockamamie to come
# precipitously to preciously
# catastrophe to catastrophic
# wracking to waking
# screamingly to screaming
# sturdy to study
# overcook to overcooked
# recital to real
# concocts to concocted
# actioneffects to actioners
# vessel to jesse
# moodily to moody
# rainwear to brainer
# apt to rapt
# fleming to filming
# clutchy to clutch
# titillation to titillating
# freebie to free
# unedited to edited
# journal to journalism
# clamor to clam
# clanging to changing
# nikita to nia
# weaker to weak
# persecution to perfection
# saintly to mainly
# patchouli to patch
# oil to boil
# unjustified to unsatisfied
# decrying to drying
# emblematic to problematic
# ageism to age
# afflicting to affecting
# varsity to variety
# planning to spanning
# illicit to elicit
# herd to heard
# imprisonment to improvement
# nerdy to nerd
# ted to ed
# justification to mystification
# maniac to mania
# seine to see
# slogs to slog
# joaquin to joan
# baca to ca
# asay to say
# annoyingly to annoying
# vertigo to averting
# opacity to city
# subsequently to subsequent
# unrecommendable to commendable
# ponderously to ponderous
# lightning to lighting
# ink to sink
# wilt to wit
# awhile to whole
# rouse to rous
# topkapi to top
# shayamalan to shyamalan
# fancied to faced
# beatnik to beat
# wim to swim
# wenders to wanders
# downside to side
# paucity to opacity
# condensation to conversation
# oclock to clock
# lobotomized to lobotomy
# preferred to referred
# transfer to transferral
# heartrending to heartening
# fundamentalist to fundamental
# devotes to devote
# bigoted to bite
# platonic to plato
# monarch to march
# philandering to pandering
# diminishes to undiminished
# tended to ended
# fading to facing
# appease to appears
# silliest to silliness
# partway to party
# chao to chaos
# assistant to distant
# learnt to learn
# marries to arrives
# amateurishness to amateurish
# discourages to courage
# regurgitated to regurgitates
# greasiest to greatest
# beached to beach
# grouper to group
# sermonizing to sermonize
# reiterates to literate
# willful to will
# evidenced to evidence
# accounting to counting
# texas to tea
# universally to universal
# festooning to swooning
# magically to magical
# flatbush to flash
# slavishly to lavishly
# henna to hanna
# ornamentation to orientation
# hamlet to let
# iv to v
# opposing to posing
# mailing to failing
# payola to pay
# hose to whose
# stepford to step
# mentality to mental
# persuasion to person
# prequel to sequel
# ostensibly to possibly
# redford to ford
# imprimatur to immature
# mirthless to ruthless
# solondzian to solondz
# amiability to ability
# personifies to personified
# greased to grease
# ferzan to fan
# heresy to cheesy
# contrary to country
# revered to reverse
# vim to m
# dialed to died
# blackboard to backyard
# alliance to allegiance
# culminates to urinates
# bus to us
# temerity to merit
# winding to winning
# majorly to major
# amber to chamber
# detracts to detract
# verbinski to vein
# loitering to altering
# nuked to naked
# alex to le
# nc to n
# ihops to hop
# hormone to home
# inquisition to inquisitive
# ineffectual to effect
# juggle to juggler
# juxtapose to pose
# takeoff to take
# melodramatics to melodramatic
# inflated to inflate
# faintly to faint
# untidy to untidily
# elaborateness to elaborate
# elan to lan
# treacherous to teacher
# guillermo to giler
# wincingly to winningly
# nauseatingly to nauseating
# villians to villain
# introduced to introduce
# sampler to sample
# bumping to bump
# etoiles to iles
# rationale to national
# laurel to lauren
# evenhanded to handed
# installation to distillation
# vinnie to minnie
# spitting to sitting
# hanson to son
# investigating to investigation
# jettisons to jettisoned
# meddling to middling
# wallow to allow
# debases to base
# grinding to grinning
# lopsided to sided
# rep to re
# delibrately to deliberately
# obtuse to use
# unapproachable to unreachable
# windbag to wind
# drone to done
# inanely to insanely
# cacophony to phony
# prattle to rattled
# yacht to act
# flowed to flow
# matheson to athon
# puke to ke
# injured to conjured
# rack to crack
# senior to tenor
# fiftysomething to something
# loudly to loud
# individually to individual
# prepubescent to pubescent
# squinting to squint
# glorifying to horrifying
# software to stare
# sluggishly to sluggish
# nap to na
# kilner to killer
# itching to switching
# morphed to morph
# accomplishing to accomplish
# dissatisfied to satisfied
# godawful to awful
# slug to sl
# longs to long
# frisk to risk
# alley to valley
# snoozy to snooze
# glibly to glib
# eurotrash to trash
# bicycle to cycle
# inflict to inflicted
# prop to pro
# sourness to shortness
# highfalutin to high
# corkscrew to crew
# begets to begs
# writerdirectorproducer to writerdirector
# portal to port
# selfish to self
# banging to aging
# salesmanship to gamesmanship
# divertingly to diverting
# headbangingly to banging
# respectful to respect
# coffin to con
# fuhgeddaboutit to bout
# egg to e
# hinted to hint
# starred to started
# creaking to creating
# rusty to crusty
# dramatist to dramatics
# overreaches to preaches
# spinoffs to spinoff
# stalk to talk
# bradbury to brady
# wachowski to sychowski
# rekindled to rekindle
# kathleen to athlete
# soliah to solid
# upcoming to coming
# sla to slap
# emily to emptily
# flaunt to flat
# writhing to writing
# unoriginality to originality
# faultlessly to ruthlessly
# lethal to lethally
# weapon to weaponry
# knowingness to knowing
# scatological to ecological
# proctologist to protagonist
# abruptly to abrupt
# soppy to sloppy
# regan to regain
# signify to sign
# jovovich to voice
# sanctified to satisfied
# alarmed to armed
# wielding to wedding
# staple to stale
# programming to program
# pointlessness to pointless
# bonbon to bon
# jaundiced to janice
# cliffsnotes to cliff
# cart to art
# outcast to cast
# chipper to chip
# derails to rail
# plum to plumb
# preprogrammed to program
# guideline to guide
# cleverer to clever
# teaching to aching
# timeline to time
# russos to russo
# ephemeral to phenomenal
# wrestle to wrestler
# chloroform to form
# handkerchief to chief
# helpfully to helpful
# succinct to suit
# locate to late
# exhaust to exhausted
# tonga to ton
# boulevard to board
# soapdish to soap
# glue to glued
# schwartzman to charm
# fond to found
# oafish to fish
# impersonating to impersonation
# relentlessness to relentless
# videogame to vidgame
# sleekly to sleek
# weather to weathered
# loosens to loose
# skolnick to slick
# polishing to publishing
# panther to another
# geeky to geek
# waradventure to adventure
# dissolve to discover
# outrun to run
# swaggering to staggering
# underwood to underworld
# marginalization to imagination
# loom to gloom
# dreamer to dream
# dogwalker to walker
# benign to benigni
# entirety to entire
# envy to levy
# kazmierski to amir
# unsuspenseful to suspenseful
# flocking to looking
# spray to pray
# norman to norma
# jewison to wilson
# ultraviolent to violent
# stupider to stupid
# dirk to irk
# csokas to coast
# unconnected to connected
# undeveloped to developed
# canter to ante
# rehashing to rehash
# humourless to humorless
# nominal to normal
# arquette to marquee
# cameron to cameo
# mate to mat
# trivial to rival
# obliviousness to obviousness
# dawdles to dawdle
# bludgeon to bludgeoning
# unconscious to conscious
# crock to rock
# convicted to convinced
# felon to el
# relevancy to irrelevancy
# bothersome to others
# earnestly to earnest
# embarrassing to unembarrassing
# newly to new
# automated to automatic
# ribbing to cribbing
# cheating to eating
# betray to betrayal
# yankee to yank
# cheerful to cheerfully
# accordionharmonicabanjo to according
# baggy to bag
# carnival to rival
# stretching to stretch
# rhyme to rye
# oriental to rental
# surfacing to surfing
# instant to instantly
# deaf to def
# gnat to na
# racehorse to horse
# collectible to collective
# juncture to nature
# enervated to generated
# preamble to ramble
# materializes to material
# slumber to slummer
# unmolested to molested
# haughtiness to ugliness
# regrettably to forgettably
# clambake to lamb
# army to arm
# reliably to reliable
# freeze to freezer
# luxury to lux
# boasted to boast
# clearer to clear
# furry to fury
# lapdance to dance
# skating to sting
# interspliced to spliced
# sketchbook to sketch
# marisa to marina
# tomei to tome
# deficiency to efficiency
# metaphoric to metaphor
# drabness to dress
# endemic to demi
# bloodless to oodles
# purported to purport
# pathologically to pathological
# avenges to avenger
# trippy to trip
# tweedy to weepy
# canning to cunning
# stockbroker to stroke
# repairing to pairing
# yearn to year
# airborne to born
# nude to de
# showiness to slowness
# qualls to qual
# indiana to indian
# han to hand
# offense to offensive
# wally to wall
# wolodarsky to woody
# jarvis to avis
# coolidge to collide
# ballpoint to ballot
# columnist to column
# offered to offer
# extraterrestrial to material
# sandrine to andie
# goat to got
# tuneless to unless
# shuns to shu
# hinged to hinge
# crotch to scotch
# thinner to inner
# grittiest to prettiest
# lanie to lane
# harland to heartland
# rosenbaum to rose
# watson to wanton
# unwrapped to wrapped
# recoiling to roiling
# linda to lina
# fiorentino to foreign
# indigestible to indigestion
# guided to guide
# sharpens to sharp
# meaningness to meaningless
# erase to ease
# repeat to repeated
# deconstruct to construct
# daydreaming to daydream
# yuks to yu
# vaulting to acting
# stoned to stone
# veiled to veil
# honed to phoned
# airport to port
# security to insecurity
# unmoved to moved
# repackaged to prepackaged
# disclosure to closure
# mississippi to miss
# rocker to rock
# miscasts to miscast
# estate to state
# danilo to dani
# donati to dot
# spinotti to penotti
# insisted to instead
# slipshod to slip
# gown to grown
# tuna to na
# hoppy to choppy
# penis to pen
# gilligan to gilliam
# jag to j
# gee to geek
# moot to mo
# hysterical to hysteric
# disquisition to inquisition
# hooey to hey
# desplechin to delhi
# scent to cent
# farmer to farm
# battling to batting
# depersonalization to personality
# unwittingly to unremittingly
# festive to fest
# levant to relevant
# skate to kate
# pausing to using
# poodle to pool
# heaviest to heist
# noodle to oodles
# perpetrator to perpetrated
# dingo to ing
# sprinkling to sparkling
# belushi to blush
# likableness to likable
# huggy to hug
# deflates to deflated
# spiritedness to spirited
# numbs to numb
# dampens to damn
# townsend to owned
# egyptian to egypt
# demigod to demi
# integral to internal
# fog to flog
# sings to sing
# completed to complete
# pretense to pretence
# perplexed to peopled
# elegiacally to elegiac
# ryanovich to tanovic
# peg to pg
# ja to j
# kurupt to kurt
# benefitted to benefited
# transplanted to transplant
# scrappy to crappy
# elementary to element
# deficient to efficient
# gob to go
# pasteurized to plastered
# retch to stretch
# crème to crime
# brûlée to re
# multifaceted to ultimate
# shelved to served
# earthbound to around
# dank to dan
# melodramacharacter to dramacharacter
# stinky to stink
# subservient to subsequent
# brandishing to ravishing
# financial to facial
# extortion to emotion
# glacier to uglier
# touchy to touch
# feely to feel
# mindedness to sidedness
# deconstructionist to deconstruction
# vanishes to vanished
# ugliest to list
# colonialist to colonialism
# mute to muted
# met to et
# subjecting to subject
# resnick to nick
# pound to pond
# lingo to lin
# brotherly to brother
# petroni to petri
# akasha to ash
# coeducational to educational
# fraternity to rarity
# kappa to pa
# rho to ho
# alpha to ala
# phi to hi
# outrunning to running
# quiver to ver
# spencer to specter
# tracy to racy
# bottomless to bottomlessly
# charity to clarity
# clink to link
# frenzied to fried
# prospective to perspective
# embroiled to embroils
# stupor to por
# elapse to lapse
# boiler to boil
# murdering to murder
# interlocking to introducing
# scandinavian to canadian
# settler to settle
# sailboaters to sailor
# midlevel to level
# metaphorically to metaphorical
# dumbest to best
# mysticism to mystic
# mystifying to satisfying
# novella to novel
# fied to field
# schooling to school
# murkiest to murk
# apallingly to appalling
# thereof to hero
# portable to portal
# stupidly to stupid
# migraine to grain
# spoon to soon
# feeding to feeling
# arrested to arrest
# baller to ball
# forgetting to getting
# retain to retains
# lulling to pulling
# allergy to gallery
# unavailable to available
# influx to flux
# liquid to fluid
# gallagher to gallery
# dishonor to honor
# disconnected to disconnect
# somnolent to moment
# mummified to unified
# hallway to halfway
# windup to wind
# dislike to like
# mating to acting
# leavitt to levity
# noxious to obnoxious
# louder to loud
# ponytail to pony
# squandered to squander
# criminally to criminal
# thirsty to thirst
# deli to del
# excrescence to presence
# consumption to consuming
# belonged to belong
# beta to bet
# delta to del
# expulsion to explosion
# crosscut to cross
# shun to shu
# fatigue to figure
# gi to cgi
# clunk to clunky
# overtime to everytime
# mirror to minor
# communism to community
# prompting to opting
# muffled to ruffle
# costumey to costume
# passivity to passive
# ploy to employ
# kegger to keg
# sounded to sound
# pitcher to pitch
# thrall to enthrall
# investing to inventing
# emi to em
# malfitano to mafia
# domingo to domino
# commonly to common
# hire to hired
# mismatched to matched
# asinine to nine
# solved to unsolved
# kvetch to sketch
# diluted to dilutes
# gravitas to gravity
# placeholder to placed
# ergo to ego
# unpicked to picked
# vine to vin
# afforded to afford
# springsteen to spring
# asbury to buy
# avoided to avoid
# swamped to shaped
# conciliatory to obligatory
# rhetorical to rhetoric
# heaviness to heaviest
# synchronized to chronicle
# swimmer to wimmer
# wool to woo
# wetsuit to suit
# faking to king
# mellow to mell
# carbon to cuaron
# intends to tends
# mangle to angle
# slowtime to showtime
# limping to lisping
# microwave to crave
# basted to based
# gravy to gray
# distributor to instructor
# comicthriller to thriller
# aboul to abdul
# finder to find
# twentieth to teeth
# legitimate to ultimate
# extensively to extensive
# resolve to resolved
# bolly to boll
# saldanha to dana
# adherence to adhere
# swap to sap
# depart to departs
# montia to monica
# montied to mounted
# pandered to pander
# heartless to artless
# ratner to rather
# elmore to more
# sen to send
# hapless to shapeless
# syndrome to rom
# sushi to us
# swamp to swap
# doubled to double
# tel to tell
# aviv to iv
# rome to rom
# threaten to threatens
# upstage to upstaged
# warpath to wrath
# devilish to devil
# pretentiously to pretentious
# overpower to overpowered
# bong to ong
# downing to drowning
# alcoholic to cool
# beverage to average
# brimful to brim
# respected to respect
# navajo to naval
# specious to precious
# hoo to hook
# fictitious to fiction
# strainingly to straining
# wandered to wander
# gantzes to gantz
# ballhaus to ballast
# spurt to put
# baz to ba
# luhrmann to fuhrman
# causing to casing
# smelly to smell
# despising to dressing
# casually to casual
# unceasing to casing
# bell to belly
# suffocated to suffocate
# munchausen to munch
# proxy to pro
# mum to um
# punish to push
# adore to adored
# pancake to cake
# sandal to scandal
# thuggery to hugger
# defunct to deft
# cleopatra to clear
# bundle to bungle
# diffuses to infuses
# uberviolence to violence
# clericks to click
# smoothes to smooth
# lent to let
# atonal to tonal
# demonizes to demon
# gifting to lifting
# vomit to mit
# patter to pattern
# remainder to reminder
# jed to ed
# violin to lin
# unlistenable to unstable
# lowering to flowering
# booming to booking
# bass to ass
# linguistic to injustice
# fumbling to bumbling
# whisper to whimper
# cigarette to care
# roisterous to boisterous
# christophe to christopher
# honoré to honor
# similarity to similar
# gymkata to mat
# howie to owe
# firestorm to storm
# fingernail to finger
# instinctively to distinctive
# crawled to scrawled
# disquiet to quiet
# reductionist to reduction
# feelgood to flood
# omnipotent to potent
# affronted to front
# secularist to secular
# antler to banter
# shorn to horn
# researcher to research
# lite to lit
# obsolete to sole
# malediction to diction
# grapple to apple
# irrevocably to irrevocable
# disintegration to disintegrating
# flute to fluke
# meltdown to letdown
# stupidest to stupid
# violates to violated
# throated to throat
# staleness to sameness
# slummy to scummy
# comedythriller to comicthriller
# nrelentingly to unrelentingly
# No. new words: 1514

# %%
with open("../resources/datasets/StanfordSentimentTreebank/split/test-new-words.json", "w") as f :
    f.write(json.dumps(dataset.new_words, indent=4))

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    f"../resources/output/{dataset_name}/checkpoint-2500",
    num_labels=dataset.n_classes
)
# Out:
# c:\Users\T-Gamer\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\_utils.py:133: UserWarning: Failed to initialize NumPy: module compiled against API version 0x10 but this version of numpy is 0xf (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:68.)
#   t = torch.tensor([], dtype=storage.dtype, device=storage._untyped().device)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(13732, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (1): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (2): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (3): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (4): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (5): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
sentence_ids, predictions = [], []
n_batches = math.ceil(len(dataset) / batch_size)
for batch in range(n_batches) :
    print("Batch", batch + 1, "of", n_batches)
    input_dict = dataset[batch * batch_size : (batch + 1) * batch_size]
    preds = model.forward(input_ids=input_dict['input_ids'], attention_mask=input_dict['attention_mask'])
    sentence_ids += input_dict['sentence_ids']
    predictions  += [float(logit[0]) for logit in preds['logits']]
prediction_column = pd.Series(predictions, index=sentence_ids, name="predictions")
# Out:
# Batch 1 of 139
# Batch 2 of 139
# Batch 3 of 139
# Batch 4 of 139
# Batch 5 of 139
# Batch 6 of 139
# Batch 7 of 139
# Batch 8 of 139
# Batch 9 of 139
# Batch 10 of 139
# Batch 11 of 139
# Batch 12 of 139
# Batch 13 of 139
# Batch 14 of 139
# Batch 15 of 139
# Batch 16 of 139
# Batch 17 of 139
# Batch 18 of 139
# Batch 19 of 139
# Batch 20 of 139
# Batch 21 of 139
# Batch 22 of 139
# Batch 23 of 139
# Batch 24 of 139
# Batch 25 of 139
# Batch 26 of 139
# Batch 27 of 139
# Batch 28 of 139
# Batch 29 of 139
# Batch 30 of 139
# Batch 31 of 139
# Batch 32 of 139
# Batch 33 of 139
# Batch 34 of 139
# Batch 35 of 139
# Batch 36 of 139
# Batch 37 of 139
# Batch 38 of 139
# Batch 39 of 139
# Batch 40 of 139
# Batch 41 of 139
# Batch 42 of 139
# Batch 43 of 139
# Batch 44 of 139
# Batch 45 of 139
# Batch 46 of 139
# Batch 47 of 139
# Batch 48 of 139
# Batch 49 of 139
# Batch 50 of 139
# Batch 51 of 139
# Batch 52 of 139
# Batch 53 of 139
# Batch 54 of 139
# Batch 55 of 139
# Batch 56 of 139
# Batch 57 of 139
# Batch 58 of 139
# Batch 59 of 139
# Batch 60 of 139
# Batch 61 of 139
# Batch 62 of 139
# Batch 63 of 139
# Batch 64 of 139
# Batch 65 of 139
# Batch 66 of 139
# Batch 67 of 139
# Batch 68 of 139
# Batch 69 of 139
# Batch 70 of 139
# Batch 71 of 139
# Batch 72 of 139
# Batch 73 of 139
# Batch 74 of 139
# Batch 75 of 139
# Batch 76 of 139
# Batch 77 of 139
# Batch 78 of 139
# Batch 79 of 139
# Batch 80 of 139
# Batch 81 of 139
# Batch 82 of 139
# Batch 83 of 139
# Batch 84 of 139
# Batch 85 of 139
# Batch 86 of 139
# Batch 87 of 139
# Batch 88 of 139
# Batch 89 of 139
# Batch 90 of 139
# Batch 91 of 139
# Batch 92 of 139
# Batch 93 of 139
# Batch 94 of 139
# Batch 95 of 139
# Batch 96 of 139
# Batch 97 of 139
# Batch 98 of 139
# Batch 99 of 139
# Batch 100 of 139
# Batch 101 of 139
# Batch 102 of 139
# Batch 103 of 139
# Batch 104 of 139
# Batch 105 of 139
# Batch 106 of 139
# Batch 107 of 139
# Batch 108 of 139
# Batch 109 of 139
# Batch 110 of 139
# Batch 111 of 139
# Batch 112 of 139
# Batch 113 of 139
# Batch 114 of 139
# Batch 115 of 139
# Batch 116 of 139
# Batch 117 of 139
# Batch 118 of 139
# Batch 119 of 139
# Batch 120 of 139
# Batch 121 of 139
# Batch 122 of 139
# Batch 123 of 139
# Batch 124 of 139
# Batch 125 of 139
# Batch 126 of 139
# Batch 127 of 139
# Batch 128 of 139
# Batch 129 of 139
# Batch 130 of 139
# Batch 131 of 139
# Batch 132 of 139
# Batch 133 of 139
# Batch 134 of 139
# Batch 135 of 139
# Batch 136 of 139
# Batch 137 of 139
# Batch 138 of 139
# Batch 139 of 139

# %%
dataset_with_preds_df = pd.concat([dataset_df, prediction_column], axis=1)

# %%
if not os.path.exists(output_dir) :
    os.makedirs(output_dir)
dataset_with_preds_df.to_csv(f"{output_dir}/Predictions.csv")

# %%
dataset_with_preds_df
# Out:
#                                                     text  phrase_id     class  \
# 3                                 effective tepid biopic      13995  0.513890
# 4      sometimes like go movie fun wasabi good place ...      14123  0.736110
# 5      emerges something rare issue movie s honest ke...      13999  0.861110
# 6      film provides great insight neurotic mindset c...      14498  0.597220
# 7         offer rare combination entertainment education      14351  0.833330
# ...                                                  ...        ...       ...
# 11621                         imaginative comedythriller      13851  0.777780
# 11623                                rare beautiful film      18182  0.916670
# 11626                          hilarious romantic comedy      23211  0.888890
# 11628                            never sink exploitation      26177  0.625000
# 11798                              u nrelentingly stupid     141831  0.069444
#
#        predictions
# 3         0.513960
# 4         0.512431
# 5         0.502496
# 6         0.508084
# 7         0.517323
# ...            ...
# 11621     0.517282
# 11623     0.518571
# 11626     0.519198
# 11628     0.517020
# 11798     0.482928
#
# [2210 rows x 4 columns]

# %%
hits, total = 0, 0
for _, row in dataset_with_preds_df.iterrows() :
    total += 1
    pred  = row["predictions"] >= .5
    label = row["class"]       >= .5
    if pred == label : 
        hits += 1
accuracy = hits / total
accuracy
# Out:
# 0.5144796380090497

# %%
hits, total = 0, 0
for _, row in dataset_with_preds_df.iterrows() :
    total += 1
    pred  = row["predictions"]
    label = row["class"]
    diff = label - pred
    hits += abs(diff)
avg_dev = hits / total
avg_dev
# Out:
# 0.22779676955529413

# %%
true_positives, true_negatives, false_positives, false_negatives = 0, 0, 0, 0
for _, row in dataset_with_preds_df.iterrows() :
    pred  = row["predictions"] >= .5
    label = row["class"]       >= .5
    if pred == label :
        if pred :
            true_positives  += 1
        else :
            true_negatives  += 1
    else :
        if pred :
            false_positives += 1
        else :
            false_negatives += 1
print(true_positives, true_negatives, false_positives, false_negatives)
# Out:
# 764 373 726 347

# %%
precision = true_positives / (true_positives + false_positives)
precision
# Out:
# 0.512751677852349

# %%
recall = true_positives / (true_positives + false_negatives)
recall
# Out:
# 0.6876687668766877

# %%
f1 = (2 * precision * recall) / (precision + recall)
f1
# Out:
# 0.5874663590926567
